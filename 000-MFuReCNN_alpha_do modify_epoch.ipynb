# %% [markdown]
# <h1>MODEL TRAINER</h1>

# %%
#LOAD DEPENDENCIES
import os
import cv2
import time
import pickle
import logging
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras import applications
from tensorflow.keras import Model, layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import AveragePooling2D, AlphaDropout, Activation, Add, BatchNormalization, Concatenate, Layer, ReLU, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout

from tensorflow.keras.applications.efficientnet import EfficientNetB0 as trainable_model_a
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2 as trainable_model_b
from tensorflow.keras.applications.resnet_v2 import ResNet50V2 as trainable_model_c

#PREVENT ERROR UNCESSARY MESSAGES
tf.get_logger().setLevel(logging.ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
#LOAD THE DATA
train_data_dir = "data/train/"
validation_data_dir = "data/validation/"
test_data_dir = "data/test/"
img_rows, img_cols = 224, 224
input_shape = (img_rows,img_cols,3)
model_input = Input(shape=input_shape)
print("Data folders found!")
print("The Input size is set to ", model_input)
# Out:
# Data folders found!
# The Input size is set to  KerasTensor(type_spec=TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'")

# %%
#Set constants
batch_size = 8
epochs = 25
optimizer = Adam(learning_rate= 0.00001)
architecture = 'MFuReCNN_alpha_do_Learning_rate_0.01'

DCNN_A = 'DCNN_A'
DCNN_B = 'DCNN_B'
DCNN_C = 'DCNN_C'

# %%
#DATA GENERATORS
#Augment Training Data
train_datagen = ImageDataGenerator(rescale = 1. / 255,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   rotation_range=45,
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   height_shift_range=0.1,
                                   width_shift_range=0.1,
                                   fill_mode='constant',
                                   brightness_range=[0.1, 1.0])

val_datagen = ImageDataGenerator(rescale = 1. / 255)

test_datagen = ImageDataGenerator(rescale = 1. / 255)

train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_rows,img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        seed=42,
        classes=['0_normal', 
                 '1_ulcerative_colitis', 
                 '2_polyps', 
                 '3_esophagitis'])

validation_generator = val_datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_rows,img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        seed=42,
        shuffle=False,
        classes=['0_normal', 
                 '1_ulcerative_colitis', 
                 '2_polyps', 
                 '3_esophagitis'])

test_generator = test_datagen.flow_from_directory(
        test_data_dir,
        target_size=(img_rows,img_cols),
        batch_size=batch_size,
        class_mode='categorical',
        seed=42,
        shuffle=False,
        classes=['0_normal', 
                 '1_ulcerative_colitis', 
                 '2_polyps', 
                 '3_esophagitis'])

#CHECK THE NUMBER OF SAMPLES
nb_train_samples = len(train_generator.filenames)
nb_validation_samples = len(validation_generator.filenames)
nb_test_samples = len(test_generator.filenames)


print("Train samples:", nb_train_samples)
print("Validation samples:", nb_validation_samples)
print("Test samples:", nb_test_samples)

if nb_train_samples == 0:
    print("NO DATA TRAIN FOUND! Please check your train data path and folders!")
else:
    print("Train samples found!")
    
if nb_validation_samples == 0:
    print("NO DATA VALIDATION FOUND! Please check your validation data path and folders!")
    print("Check the data folders first!")
else:
    print("Validation samples found!")
    
if nb_test_samples == 0:
    print("NO DATA TEST FOUND! Please check your test data path and folders!")
    print("Check the data folders first!")
else:
    print("Test samples found!")

#check the class indices
train_generator.class_indices
validation_generator.class_indices
test_generator.class_indices

#true labels
Y_test=validation_generator.classes
test_labels = test_generator.classes

num_classes= len(train_generator.class_indices)

print('Model set to train', num_classes, 'classes')

if nb_train_samples and nb_validation_samples and nb_test_samples > 0:
    print("Generators are set!")
    print("Check if dataset is complete and has no problems before proceeding.")
# Out:
# Found 3200 images belonging to 4 classes.
# Found 2000 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
# Train samples: 3200
# Validation samples: 2000
# Test samples: 800
# Train samples found!
# Validation samples found!
# Test samples found!
# Model set to train 4 classes
# Generators are set!
# Check if dataset is complete and has no problems before proceeding.

# %%
# Model
#EfficientNetB0

builder_a = DCNN_A + '_builder'

#TRANSFER LEARNING
def builder_a(model_input):
    builder_a = trainable_model_a(weights='imagenet', 
                                    include_top=False, 
                                    input_tensor = model_input)

#PARTIAL LAYER FREEZING
    for layer in builder_a.layers:
        layer.trainable = False
        
    for layer in builder_a.layers:
        layer._name = layer.name + '_' + DCNN_A
        
    for BatchNormalization in builder_a.layers:
        BatchNormalization.trainable = False

    x = builder_a.layers[-17].output
    
#AUXILIARY FUSING LAYER (AuxFL)
    x = Conv2D(192, 1, padding='valid', activation='selu', kernel_initializer='lecun_normal')(x)
    x = AveragePooling2D(1, 1)(x)
    x = AlphaDropout(0.2)(x)

    dcnn_a = Model(inputs=builder_a.input, outputs=x, name=DCNN_A)
    return dcnn_a

#INITIALIZE THE MODEL
dcnn_a = builder_a(model_input)

#PLOT THE MODEL STRUCTURE
print("PLEASE CHECK THE ENTIRE MODEL UP TO THE END")

dcnn_a.summary()

print("successfully built!")
# Out:
# PLEASE CHECK THE ENTIRE MODEL UP TO THE END
# Model: "DCNN_A"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1_DCNN_A (InputLayer  [(None, 224, 224, 3)]        0         []
#  )
#
#  rescaling_DCNN_A (Rescalin  (None, 224, 224, 3)          0         ['input_1_DCNN_A[0][0]']
#  g)
#
#  normalization_DCNN_A (Norm  (None, 224, 224, 3)          7         ['rescaling_DCNN_A[0][0]']
#  alization)
#
#  rescaling_1_DCNN_A (Rescal  (None, 224, 224, 3)          0         ['normalization_DCNN_A[0][0]']
#  ing)
#
#  stem_conv_pad_DCNN_A (Zero  (None, 225, 225, 3)          0         ['rescaling_1_DCNN_A[0][0]']
#  Padding2D)
#
#  stem_conv_DCNN_A (Conv2D)   (None, 112, 112, 32)         864       ['stem_conv_pad_DCNN_A[0][0]']
#
#  stem_bn_DCNN_A (BatchNorma  (None, 112, 112, 32)         128       ['stem_conv_DCNN_A[0][0]']
#  lization)
#
#  stem_activation_DCNN_A (Ac  (None, 112, 112, 32)         0         ['stem_bn_DCNN_A[0][0]']
#  tivation)
#
#  block1a_dwconv_DCNN_A (Dep  (None, 112, 112, 32)         288       ['stem_activation_DCNN_A[0][0]
#  thwiseConv2D)                                                      ']
#
#  block1a_bn_DCNN_A (BatchNo  (None, 112, 112, 32)         128       ['block1a_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block1a_activation_DCNN_A   (None, 112, 112, 32)         0         ['block1a_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block1a_se_squeeze_DCNN_A   (None, 32)                   0         ['block1a_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block1a_se_reshape_DCNN_A   (None, 1, 1, 32)             0         ['block1a_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block1a_se_reduce_DCNN_A (  (None, 1, 1, 8)              264       ['block1a_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block1a_se_expand_DCNN_A (  (None, 1, 1, 32)             288       ['block1a_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block1a_se_excite_DCNN_A (  (None, 112, 112, 32)         0         ['block1a_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block1a_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block1a_project_conv_DCNN_  (None, 112, 112, 16)         512       ['block1a_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block1a_project_bn_DCNN_A   (None, 112, 112, 16)         64        ['block1a_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block2a_expand_conv_DCNN_A  (None, 112, 112, 96)         1536      ['block1a_project_bn_DCNN_A[0]
#   (Conv2D)                                                          [0]']
#
#  block2a_expand_bn_DCNN_A (  (None, 112, 112, 96)         384       ['block2a_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block2a_expand_activation_  (None, 112, 112, 96)         0         ['block2a_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block2a_dwconv_pad_DCNN_A   (None, 113, 113, 96)         0         ['block2a_expand_activation_DC
#  (ZeroPadding2D)                                                    NN_A[0][0]']
#
#  block2a_dwconv_DCNN_A (Dep  (None, 56, 56, 96)           864       ['block2a_dwconv_pad_DCNN_A[0]
#  thwiseConv2D)                                                      [0]']
#
#  block2a_bn_DCNN_A (BatchNo  (None, 56, 56, 96)           384       ['block2a_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block2a_activation_DCNN_A   (None, 56, 56, 96)           0         ['block2a_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block2a_se_squeeze_DCNN_A   (None, 96)                   0         ['block2a_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block2a_se_reshape_DCNN_A   (None, 1, 1, 96)             0         ['block2a_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block2a_se_reduce_DCNN_A (  (None, 1, 1, 4)              388       ['block2a_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block2a_se_expand_DCNN_A (  (None, 1, 1, 96)             480       ['block2a_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block2a_se_excite_DCNN_A (  (None, 56, 56, 96)           0         ['block2a_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block2a_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block2a_project_conv_DCNN_  (None, 56, 56, 24)           2304      ['block2a_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block2a_project_bn_DCNN_A   (None, 56, 56, 24)           96        ['block2a_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block2b_expand_conv_DCNN_A  (None, 56, 56, 144)          3456      ['block2a_project_bn_DCNN_A[0]
#   (Conv2D)                                                          [0]']
#
#  block2b_expand_bn_DCNN_A (  (None, 56, 56, 144)          576       ['block2b_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block2b_expand_activation_  (None, 56, 56, 144)          0         ['block2b_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block2b_dwconv_DCNN_A (Dep  (None, 56, 56, 144)          1296      ['block2b_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block2b_bn_DCNN_A (BatchNo  (None, 56, 56, 144)          576       ['block2b_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block2b_activation_DCNN_A   (None, 56, 56, 144)          0         ['block2b_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block2b_se_squeeze_DCNN_A   (None, 144)                  0         ['block2b_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block2b_se_reshape_DCNN_A   (None, 1, 1, 144)            0         ['block2b_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block2b_se_reduce_DCNN_A (  (None, 1, 1, 6)              870       ['block2b_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block2b_se_expand_DCNN_A (  (None, 1, 1, 144)            1008      ['block2b_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block2b_se_excite_DCNN_A (  (None, 56, 56, 144)          0         ['block2b_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block2b_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block2b_project_conv_DCNN_  (None, 56, 56, 24)           3456      ['block2b_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block2b_project_bn_DCNN_A   (None, 56, 56, 24)           96        ['block2b_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block2b_drop_DCNN_A (Dropo  (None, 56, 56, 24)           0         ['block2b_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block2b_add_DCNN_A (Add)    (None, 56, 56, 24)           0         ['block2b_drop_DCNN_A[0][0]',
#                                                                      'block2a_project_bn_DCNN_A[0]
#                                                                     [0]']
#
#  block3a_expand_conv_DCNN_A  (None, 56, 56, 144)          3456      ['block2b_add_DCNN_A[0][0]']
#   (Conv2D)
#
#  block3a_expand_bn_DCNN_A (  (None, 56, 56, 144)          576       ['block3a_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block3a_expand_activation_  (None, 56, 56, 144)          0         ['block3a_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block3a_dwconv_pad_DCNN_A   (None, 59, 59, 144)          0         ['block3a_expand_activation_DC
#  (ZeroPadding2D)                                                    NN_A[0][0]']
#
#  block3a_dwconv_DCNN_A (Dep  (None, 28, 28, 144)          3600      ['block3a_dwconv_pad_DCNN_A[0]
#  thwiseConv2D)                                                      [0]']
#
#  block3a_bn_DCNN_A (BatchNo  (None, 28, 28, 144)          576       ['block3a_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block3a_activation_DCNN_A   (None, 28, 28, 144)          0         ['block3a_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block3a_se_squeeze_DCNN_A   (None, 144)                  0         ['block3a_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block3a_se_reshape_DCNN_A   (None, 1, 1, 144)            0         ['block3a_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block3a_se_reduce_DCNN_A (  (None, 1, 1, 6)              870       ['block3a_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block3a_se_expand_DCNN_A (  (None, 1, 1, 144)            1008      ['block3a_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block3a_se_excite_DCNN_A (  (None, 28, 28, 144)          0         ['block3a_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block3a_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block3a_project_conv_DCNN_  (None, 28, 28, 40)           5760      ['block3a_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block3a_project_bn_DCNN_A   (None, 28, 28, 40)           160       ['block3a_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block3b_expand_conv_DCNN_A  (None, 28, 28, 240)          9600      ['block3a_project_bn_DCNN_A[0]
#   (Conv2D)                                                          [0]']
#
#  block3b_expand_bn_DCNN_A (  (None, 28, 28, 240)          960       ['block3b_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block3b_expand_activation_  (None, 28, 28, 240)          0         ['block3b_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block3b_dwconv_DCNN_A (Dep  (None, 28, 28, 240)          6000      ['block3b_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block3b_bn_DCNN_A (BatchNo  (None, 28, 28, 240)          960       ['block3b_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block3b_activation_DCNN_A   (None, 28, 28, 240)          0         ['block3b_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block3b_se_squeeze_DCNN_A   (None, 240)                  0         ['block3b_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block3b_se_reshape_DCNN_A   (None, 1, 1, 240)            0         ['block3b_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block3b_se_reduce_DCNN_A (  (None, 1, 1, 10)             2410      ['block3b_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block3b_se_expand_DCNN_A (  (None, 1, 1, 240)            2640      ['block3b_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block3b_se_excite_DCNN_A (  (None, 28, 28, 240)          0         ['block3b_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block3b_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block3b_project_conv_DCNN_  (None, 28, 28, 40)           9600      ['block3b_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block3b_project_bn_DCNN_A   (None, 28, 28, 40)           160       ['block3b_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block3b_drop_DCNN_A (Dropo  (None, 28, 28, 40)           0         ['block3b_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block3b_add_DCNN_A (Add)    (None, 28, 28, 40)           0         ['block3b_drop_DCNN_A[0][0]',
#                                                                      'block3a_project_bn_DCNN_A[0]
#                                                                     [0]']
#
#  block4a_expand_conv_DCNN_A  (None, 28, 28, 240)          9600      ['block3b_add_DCNN_A[0][0]']
#   (Conv2D)
#
#  block4a_expand_bn_DCNN_A (  (None, 28, 28, 240)          960       ['block4a_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block4a_expand_activation_  (None, 28, 28, 240)          0         ['block4a_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block4a_dwconv_pad_DCNN_A   (None, 29, 29, 240)          0         ['block4a_expand_activation_DC
#  (ZeroPadding2D)                                                    NN_A[0][0]']
#
#  block4a_dwconv_DCNN_A (Dep  (None, 14, 14, 240)          2160      ['block4a_dwconv_pad_DCNN_A[0]
#  thwiseConv2D)                                                      [0]']
#
#  block4a_bn_DCNN_A (BatchNo  (None, 14, 14, 240)          960       ['block4a_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block4a_activation_DCNN_A   (None, 14, 14, 240)          0         ['block4a_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block4a_se_squeeze_DCNN_A   (None, 240)                  0         ['block4a_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block4a_se_reshape_DCNN_A   (None, 1, 1, 240)            0         ['block4a_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block4a_se_reduce_DCNN_A (  (None, 1, 1, 10)             2410      ['block4a_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block4a_se_expand_DCNN_A (  (None, 1, 1, 240)            2640      ['block4a_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block4a_se_excite_DCNN_A (  (None, 14, 14, 240)          0         ['block4a_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block4a_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block4a_project_conv_DCNN_  (None, 14, 14, 80)           19200     ['block4a_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block4a_project_bn_DCNN_A   (None, 14, 14, 80)           320       ['block4a_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block4b_expand_conv_DCNN_A  (None, 14, 14, 480)          38400     ['block4a_project_bn_DCNN_A[0]
#   (Conv2D)                                                          [0]']
#
#  block4b_expand_bn_DCNN_A (  (None, 14, 14, 480)          1920      ['block4b_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block4b_expand_activation_  (None, 14, 14, 480)          0         ['block4b_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block4b_dwconv_DCNN_A (Dep  (None, 14, 14, 480)          4320      ['block4b_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block4b_bn_DCNN_A (BatchNo  (None, 14, 14, 480)          1920      ['block4b_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block4b_activation_DCNN_A   (None, 14, 14, 480)          0         ['block4b_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block4b_se_squeeze_DCNN_A   (None, 480)                  0         ['block4b_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block4b_se_reshape_DCNN_A   (None, 1, 1, 480)            0         ['block4b_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block4b_se_reduce_DCNN_A (  (None, 1, 1, 20)             9620      ['block4b_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block4b_se_expand_DCNN_A (  (None, 1, 1, 480)            10080     ['block4b_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block4b_se_excite_DCNN_A (  (None, 14, 14, 480)          0         ['block4b_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block4b_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block4b_project_conv_DCNN_  (None, 14, 14, 80)           38400     ['block4b_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block4b_project_bn_DCNN_A   (None, 14, 14, 80)           320       ['block4b_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block4b_drop_DCNN_A (Dropo  (None, 14, 14, 80)           0         ['block4b_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block4b_add_DCNN_A (Add)    (None, 14, 14, 80)           0         ['block4b_drop_DCNN_A[0][0]',
#                                                                      'block4a_project_bn_DCNN_A[0]
#                                                                     [0]']
#
#  block4c_expand_conv_DCNN_A  (None, 14, 14, 480)          38400     ['block4b_add_DCNN_A[0][0]']
#   (Conv2D)
#
#  block4c_expand_bn_DCNN_A (  (None, 14, 14, 480)          1920      ['block4c_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block4c_expand_activation_  (None, 14, 14, 480)          0         ['block4c_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block4c_dwconv_DCNN_A (Dep  (None, 14, 14, 480)          4320      ['block4c_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block4c_bn_DCNN_A (BatchNo  (None, 14, 14, 480)          1920      ['block4c_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block4c_activation_DCNN_A   (None, 14, 14, 480)          0         ['block4c_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block4c_se_squeeze_DCNN_A   (None, 480)                  0         ['block4c_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block4c_se_reshape_DCNN_A   (None, 1, 1, 480)            0         ['block4c_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block4c_se_reduce_DCNN_A (  (None, 1, 1, 20)             9620      ['block4c_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block4c_se_expand_DCNN_A (  (None, 1, 1, 480)            10080     ['block4c_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block4c_se_excite_DCNN_A (  (None, 14, 14, 480)          0         ['block4c_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block4c_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block4c_project_conv_DCNN_  (None, 14, 14, 80)           38400     ['block4c_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block4c_project_bn_DCNN_A   (None, 14, 14, 80)           320       ['block4c_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block4c_drop_DCNN_A (Dropo  (None, 14, 14, 80)           0         ['block4c_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block4c_add_DCNN_A (Add)    (None, 14, 14, 80)           0         ['block4c_drop_DCNN_A[0][0]',
#                                                                      'block4b_add_DCNN_A[0][0]']
#
#  block5a_expand_conv_DCNN_A  (None, 14, 14, 480)          38400     ['block4c_add_DCNN_A[0][0]']
#   (Conv2D)
#
#  block5a_expand_bn_DCNN_A (  (None, 14, 14, 480)          1920      ['block5a_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block5a_expand_activation_  (None, 14, 14, 480)          0         ['block5a_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block5a_dwconv_DCNN_A (Dep  (None, 14, 14, 480)          12000     ['block5a_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block5a_bn_DCNN_A (BatchNo  (None, 14, 14, 480)          1920      ['block5a_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block5a_activation_DCNN_A   (None, 14, 14, 480)          0         ['block5a_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block5a_se_squeeze_DCNN_A   (None, 480)                  0         ['block5a_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block5a_se_reshape_DCNN_A   (None, 1, 1, 480)            0         ['block5a_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block5a_se_reduce_DCNN_A (  (None, 1, 1, 20)             9620      ['block5a_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block5a_se_expand_DCNN_A (  (None, 1, 1, 480)            10080     ['block5a_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block5a_se_excite_DCNN_A (  (None, 14, 14, 480)          0         ['block5a_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block5a_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block5a_project_conv_DCNN_  (None, 14, 14, 112)          53760     ['block5a_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block5a_project_bn_DCNN_A   (None, 14, 14, 112)          448       ['block5a_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block5b_expand_conv_DCNN_A  (None, 14, 14, 672)          75264     ['block5a_project_bn_DCNN_A[0]
#   (Conv2D)                                                          [0]']
#
#  block5b_expand_bn_DCNN_A (  (None, 14, 14, 672)          2688      ['block5b_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block5b_expand_activation_  (None, 14, 14, 672)          0         ['block5b_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block5b_dwconv_DCNN_A (Dep  (None, 14, 14, 672)          16800     ['block5b_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block5b_bn_DCNN_A (BatchNo  (None, 14, 14, 672)          2688      ['block5b_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block5b_activation_DCNN_A   (None, 14, 14, 672)          0         ['block5b_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block5b_se_squeeze_DCNN_A   (None, 672)                  0         ['block5b_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block5b_se_reshape_DCNN_A   (None, 1, 1, 672)            0         ['block5b_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block5b_se_reduce_DCNN_A (  (None, 1, 1, 28)             18844     ['block5b_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block5b_se_expand_DCNN_A (  (None, 1, 1, 672)            19488     ['block5b_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block5b_se_excite_DCNN_A (  (None, 14, 14, 672)          0         ['block5b_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block5b_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block5b_project_conv_DCNN_  (None, 14, 14, 112)          75264     ['block5b_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block5b_project_bn_DCNN_A   (None, 14, 14, 112)          448       ['block5b_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block5b_drop_DCNN_A (Dropo  (None, 14, 14, 112)          0         ['block5b_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block5b_add_DCNN_A (Add)    (None, 14, 14, 112)          0         ['block5b_drop_DCNN_A[0][0]',
#                                                                      'block5a_project_bn_DCNN_A[0]
#                                                                     [0]']
#
#  block5c_expand_conv_DCNN_A  (None, 14, 14, 672)          75264     ['block5b_add_DCNN_A[0][0]']
#   (Conv2D)
#
#  block5c_expand_bn_DCNN_A (  (None, 14, 14, 672)          2688      ['block5c_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block5c_expand_activation_  (None, 14, 14, 672)          0         ['block5c_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block5c_dwconv_DCNN_A (Dep  (None, 14, 14, 672)          16800     ['block5c_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block5c_bn_DCNN_A (BatchNo  (None, 14, 14, 672)          2688      ['block5c_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
# ...
#                                                                     0]']
#
#  block6a_project_conv_DCNN_  (None, 7, 7, 192)            129024    ['block6a_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block6a_project_bn_DCNN_A   (None, 7, 7, 192)            768       ['block6a_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block6b_expand_conv_DCNN_A  (None, 7, 7, 1152)           221184    ['block6a_project_bn_DCNN_A[0]
#   (Conv2D)                                                          [0]']
#
#  block6b_expand_bn_DCNN_A (  (None, 7, 7, 1152)           4608      ['block6b_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block6b_expand_activation_  (None, 7, 7, 1152)           0         ['block6b_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block6b_dwconv_DCNN_A (Dep  (None, 7, 7, 1152)           28800     ['block6b_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block6b_bn_DCNN_A (BatchNo  (None, 7, 7, 1152)           4608      ['block6b_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block6b_activation_DCNN_A   (None, 7, 7, 1152)           0         ['block6b_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block6b_se_squeeze_DCNN_A   (None, 1152)                 0         ['block6b_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block6b_se_reshape_DCNN_A   (None, 1, 1, 1152)           0         ['block6b_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block6b_se_reduce_DCNN_A (  (None, 1, 1, 48)             55344     ['block6b_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block6b_se_expand_DCNN_A (  (None, 1, 1, 1152)           56448     ['block6b_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block6b_se_excite_DCNN_A (  (None, 7, 7, 1152)           0         ['block6b_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block6b_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block6b_project_conv_DCNN_  (None, 7, 7, 192)            221184    ['block6b_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block6b_project_bn_DCNN_A   (None, 7, 7, 192)            768       ['block6b_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block6b_drop_DCNN_A (Dropo  (None, 7, 7, 192)            0         ['block6b_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block6b_add_DCNN_A (Add)    (None, 7, 7, 192)            0         ['block6b_drop_DCNN_A[0][0]',
#                                                                      'block6a_project_bn_DCNN_A[0]
#                                                                     [0]']
#
#  block6c_expand_conv_DCNN_A  (None, 7, 7, 1152)           221184    ['block6b_add_DCNN_A[0][0]']
#   (Conv2D)
#
#  block6c_expand_bn_DCNN_A (  (None, 7, 7, 1152)           4608      ['block6c_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block6c_expand_activation_  (None, 7, 7, 1152)           0         ['block6c_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block6c_dwconv_DCNN_A (Dep  (None, 7, 7, 1152)           28800     ['block6c_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block6c_bn_DCNN_A (BatchNo  (None, 7, 7, 1152)           4608      ['block6c_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block6c_activation_DCNN_A   (None, 7, 7, 1152)           0         ['block6c_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block6c_se_squeeze_DCNN_A   (None, 1152)                 0         ['block6c_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block6c_se_reshape_DCNN_A   (None, 1, 1, 1152)           0         ['block6c_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block6c_se_reduce_DCNN_A (  (None, 1, 1, 48)             55344     ['block6c_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block6c_se_expand_DCNN_A (  (None, 1, 1, 1152)           56448     ['block6c_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block6c_se_excite_DCNN_A (  (None, 7, 7, 1152)           0         ['block6c_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block6c_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block6c_project_conv_DCNN_  (None, 7, 7, 192)            221184    ['block6c_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block6c_project_bn_DCNN_A   (None, 7, 7, 192)            768       ['block6c_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block6c_drop_DCNN_A (Dropo  (None, 7, 7, 192)            0         ['block6c_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block6c_add_DCNN_A (Add)    (None, 7, 7, 192)            0         ['block6c_drop_DCNN_A[0][0]',
#                                                                      'block6b_add_DCNN_A[0][0]']
#
#  block6d_expand_conv_DCNN_A  (None, 7, 7, 1152)           221184    ['block6c_add_DCNN_A[0][0]']
#   (Conv2D)
#
#  block6d_expand_bn_DCNN_A (  (None, 7, 7, 1152)           4608      ['block6d_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block6d_expand_activation_  (None, 7, 7, 1152)           0         ['block6d_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block6d_dwconv_DCNN_A (Dep  (None, 7, 7, 1152)           28800     ['block6d_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block6d_bn_DCNN_A (BatchNo  (None, 7, 7, 1152)           4608      ['block6d_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block6d_activation_DCNN_A   (None, 7, 7, 1152)           0         ['block6d_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block6d_se_squeeze_DCNN_A   (None, 1152)                 0         ['block6d_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block6d_se_reshape_DCNN_A   (None, 1, 1, 1152)           0         ['block6d_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block6d_se_reduce_DCNN_A (  (None, 1, 1, 48)             55344     ['block6d_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block6d_se_expand_DCNN_A (  (None, 1, 1, 1152)           56448     ['block6d_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block6d_se_excite_DCNN_A (  (None, 7, 7, 1152)           0         ['block6d_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block6d_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block6d_project_conv_DCNN_  (None, 7, 7, 192)            221184    ['block6d_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block6d_project_bn_DCNN_A   (None, 7, 7, 192)            768       ['block6d_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block6d_drop_DCNN_A (Dropo  (None, 7, 7, 192)            0         ['block6d_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block6d_add_DCNN_A (Add)    (None, 7, 7, 192)            0         ['block6d_drop_DCNN_A[0][0]',
#                                                                      'block6c_add_DCNN_A[0][0]']
#
#  conv2d (Conv2D)             (None, 7, 7, 192)            37056     ['block6d_add_DCNN_A[0][0]']
#
#  average_pooling2d (Average  (None, 7, 7, 192)            0         ['conv2d[0][0]']
#  Pooling2D)
#
#  alpha_dropout (AlphaDropou  (None, 7, 7, 192)            0         ['average_pooling2d[0][0]']
#  t)
#
# ==================================================================================================
# Total params: 2949427 (11.25 MB)
# Trainable params: 37056 (144.75 KB)
# Non-trainable params: 2912371 (11.11 MB)
# __________________________________________________________________________________________________
# successfully built!

# %%
# Model
#MobileNetV2

builder_b = DCNN_B + '_builder'

#TRANSFER LEARNING
def builder_b(model_input):
    builder_b = trainable_model_b(weights='imagenet', 
                                    include_top=False, 
                                    input_tensor = model_input)

#PARTIAL LAYER FREEZING
    for layer in builder_b.layers:
        layer.trainable = False
        
    for layer in builder_b.layers:
        layer._name = layer.name + '_' + DCNN_B
        
    for BatchNormalization in builder_b.layers:
        BatchNormalization.trainable = False
    
    x = builder_b.layers[-39].output
    
#AUXILIARY FUSING LAYER (AuxFL)
    x = Conv2D(192, 8, padding='valid', activation='selu', kernel_initializer='lecun_normal')(x)
    x = AveragePooling2D(1, 1)(x)
    x = AlphaDropout(0.2)(x)

    dcnn_b = Model(inputs=builder_b.input, outputs=x, name=DCNN_B)
    return dcnn_b

#INITIALIZE THE MODEL
dcnn_b = builder_b(model_input)

#PLOT THE MODEL STRUCTURE
print("PLEASE CHECK THE ENTIRE MODEL UP TO THE END")

dcnn_b.summary()

print(" successfully built!")
# Out:
# PLEASE CHECK THE ENTIRE MODEL UP TO THE END
# Model: "DCNN_B"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1_DCNN_A_DCNN_B (Inp  [(None, 224, 224, 3)]        0         []
#  utLayer)
#
#  Conv1_DCNN_B (Conv2D)       (None, 112, 112, 32)         864       ['input_1_DCNN_A_DCNN_B[0][0]'
#                                                                     ]
#
#  bn_Conv1_DCNN_B (BatchNorm  (None, 112, 112, 32)         128       ['Conv1_DCNN_B[0][0]']
#  alization)
#
#  Conv1_relu_DCNN_B (ReLU)    (None, 112, 112, 32)         0         ['bn_Conv1_DCNN_B[0][0]']
#
#  expanded_conv_depthwise_DC  (None, 112, 112, 32)         288       ['Conv1_relu_DCNN_B[0][0]']
#  NN_B (DepthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 32)         128       ['expanded_conv_depthwise_DCNN
#  _DCNN_B (BatchNormalizatio                                         _B[0][0]']
#  n)
#
#  expanded_conv_depthwise_re  (None, 112, 112, 32)         0         ['expanded_conv_depthwise_BN_D
#  lu_DCNN_B (ReLU)                                                   CNN_B[0][0]']
#
#  expanded_conv_project_DCNN  (None, 112, 112, 16)         512       ['expanded_conv_depthwise_relu
#  _B (Conv2D)                                                        _DCNN_B[0][0]']
#
#  expanded_conv_project_BN_D  (None, 112, 112, 16)         64        ['expanded_conv_project_DCNN_B
#  CNN_B (BatchNormalization)                                         [0][0]']
#
#  block_1_expand_DCNN_B (Con  (None, 112, 112, 96)         1536      ['expanded_conv_project_BN_DCN
#  v2D)                                                               N_B[0][0]']
#
#  block_1_expand_BN_DCNN_B (  (None, 112, 112, 96)         384       ['block_1_expand_DCNN_B[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand_relu_DCNN_B  (None, 112, 112, 96)         0         ['block_1_expand_BN_DCNN_B[0][
#   (ReLU)                                                            0]']
#
#  block_1_pad_DCNN_B (ZeroPa  (None, 113, 113, 96)         0         ['block_1_expand_relu_DCNN_B[0
#  dding2D)                                                           ][0]']
#
#  block_1_depthwise_DCNN_B (  (None, 56, 56, 96)           864       ['block_1_pad_DCNN_B[0][0]']
#  DepthwiseConv2D)
#
#  block_1_depthwise_BN_DCNN_  (None, 56, 56, 96)           384       ['block_1_depthwise_DCNN_B[0][
#  B (BatchNormalization)                                             0]']
#
#  block_1_depthwise_relu_DCN  (None, 56, 56, 96)           0         ['block_1_depthwise_BN_DCNN_B[
#  N_B (ReLU)                                                         0][0]']
#
#  block_1_project_DCNN_B (Co  (None, 56, 56, 24)           2304      ['block_1_depthwise_relu_DCNN_
#  nv2D)                                                              B[0][0]']
#
#  block_1_project_BN_DCNN_B   (None, 56, 56, 24)           96        ['block_1_project_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block_2_expand_DCNN_B (Con  (None, 56, 56, 144)          3456      ['block_1_project_BN_DCNN_B[0]
#  v2D)                                                               [0]']
#
#  block_2_expand_BN_DCNN_B (  (None, 56, 56, 144)          576       ['block_2_expand_DCNN_B[0][0]'
#  BatchNormalization)                                                ]
#
#  block_2_expand_relu_DCNN_B  (None, 56, 56, 144)          0         ['block_2_expand_BN_DCNN_B[0][
#   (ReLU)                                                            0]']
#
#  block_2_depthwise_DCNN_B (  (None, 56, 56, 144)          1296      ['block_2_expand_relu_DCNN_B[0
#  DepthwiseConv2D)                                                   ][0]']
#
#  block_2_depthwise_BN_DCNN_  (None, 56, 56, 144)          576       ['block_2_depthwise_DCNN_B[0][
#  B (BatchNormalization)                                             0]']
#
#  block_2_depthwise_relu_DCN  (None, 56, 56, 144)          0         ['block_2_depthwise_BN_DCNN_B[
#  N_B (ReLU)                                                         0][0]']
#
#  block_2_project_DCNN_B (Co  (None, 56, 56, 24)           3456      ['block_2_depthwise_relu_DCNN_
#  nv2D)                                                              B[0][0]']
#
#  block_2_project_BN_DCNN_B   (None, 56, 56, 24)           96        ['block_2_project_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block_2_add_DCNN_B (Add)    (None, 56, 56, 24)           0         ['block_1_project_BN_DCNN_B[0]
#                                                                     [0]',
#                                                                      'block_2_project_BN_DCNN_B[0]
#                                                                     [0]']
#
#  block_3_expand_DCNN_B (Con  (None, 56, 56, 144)          3456      ['block_2_add_DCNN_B[0][0]']
#  v2D)
#
#  block_3_expand_BN_DCNN_B (  (None, 56, 56, 144)          576       ['block_3_expand_DCNN_B[0][0]'
#  BatchNormalization)                                                ]
#
#  block_3_expand_relu_DCNN_B  (None, 56, 56, 144)          0         ['block_3_expand_BN_DCNN_B[0][
#   (ReLU)                                                            0]']
#
#  block_3_pad_DCNN_B (ZeroPa  (None, 57, 57, 144)          0         ['block_3_expand_relu_DCNN_B[0
#  dding2D)                                                           ][0]']
#
#  block_3_depthwise_DCNN_B (  (None, 28, 28, 144)          1296      ['block_3_pad_DCNN_B[0][0]']
#  DepthwiseConv2D)
#
#  block_3_depthwise_BN_DCNN_  (None, 28, 28, 144)          576       ['block_3_depthwise_DCNN_B[0][
#  B (BatchNormalization)                                             0]']
#
#  block_3_depthwise_relu_DCN  (None, 28, 28, 144)          0         ['block_3_depthwise_BN_DCNN_B[
#  N_B (ReLU)                                                         0][0]']
#
#  block_3_project_DCNN_B (Co  (None, 28, 28, 32)           4608      ['block_3_depthwise_relu_DCNN_
#  nv2D)                                                              B[0][0]']
#
#  block_3_project_BN_DCNN_B   (None, 28, 28, 32)           128       ['block_3_project_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block_4_expand_DCNN_B (Con  (None, 28, 28, 192)          6144      ['block_3_project_BN_DCNN_B[0]
#  v2D)                                                               [0]']
#
#  block_4_expand_BN_DCNN_B (  (None, 28, 28, 192)          768       ['block_4_expand_DCNN_B[0][0]'
#  BatchNormalization)                                                ]
#
#  block_4_expand_relu_DCNN_B  (None, 28, 28, 192)          0         ['block_4_expand_BN_DCNN_B[0][
#   (ReLU)                                                            0]']
#
#  block_4_depthwise_DCNN_B (  (None, 28, 28, 192)          1728      ['block_4_expand_relu_DCNN_B[0
#  DepthwiseConv2D)                                                   ][0]']
#
#  block_4_depthwise_BN_DCNN_  (None, 28, 28, 192)          768       ['block_4_depthwise_DCNN_B[0][
#  B (BatchNormalization)                                             0]']
#
#  block_4_depthwise_relu_DCN  (None, 28, 28, 192)          0         ['block_4_depthwise_BN_DCNN_B[
#  N_B (ReLU)                                                         0][0]']
#
#  block_4_project_DCNN_B (Co  (None, 28, 28, 32)           6144      ['block_4_depthwise_relu_DCNN_
#  nv2D)                                                              B[0][0]']
#
#  block_4_project_BN_DCNN_B   (None, 28, 28, 32)           128       ['block_4_project_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block_4_add_DCNN_B (Add)    (None, 28, 28, 32)           0         ['block_3_project_BN_DCNN_B[0]
#                                                                     [0]',
#                                                                      'block_4_project_BN_DCNN_B[0]
#                                                                     [0]']
#
#  block_5_expand_DCNN_B (Con  (None, 28, 28, 192)          6144      ['block_4_add_DCNN_B[0][0]']
#  v2D)
#
#  block_5_expand_BN_DCNN_B (  (None, 28, 28, 192)          768       ['block_5_expand_DCNN_B[0][0]'
#  BatchNormalization)                                                ]
#
#  block_5_expand_relu_DCNN_B  (None, 28, 28, 192)          0         ['block_5_expand_BN_DCNN_B[0][
#   (ReLU)                                                            0]']
#
#  block_5_depthwise_DCNN_B (  (None, 28, 28, 192)          1728      ['block_5_expand_relu_DCNN_B[0
#  DepthwiseConv2D)                                                   ][0]']
#
#  block_5_depthwise_BN_DCNN_  (None, 28, 28, 192)          768       ['block_5_depthwise_DCNN_B[0][
#  B (BatchNormalization)                                             0]']
#
#  block_5_depthwise_relu_DCN  (None, 28, 28, 192)          0         ['block_5_depthwise_BN_DCNN_B[
#  N_B (ReLU)                                                         0][0]']
#
#  block_5_project_DCNN_B (Co  (None, 28, 28, 32)           6144      ['block_5_depthwise_relu_DCNN_
#  nv2D)                                                              B[0][0]']
#
#  block_5_project_BN_DCNN_B   (None, 28, 28, 32)           128       ['block_5_project_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block_5_add_DCNN_B (Add)    (None, 28, 28, 32)           0         ['block_4_add_DCNN_B[0][0]',
#                                                                      'block_5_project_BN_DCNN_B[0]
#                                                                     [0]']
#
#  block_6_expand_DCNN_B (Con  (None, 28, 28, 192)          6144      ['block_5_add_DCNN_B[0][0]']
#  v2D)
#
#  block_6_expand_BN_DCNN_B (  (None, 28, 28, 192)          768       ['block_6_expand_DCNN_B[0][0]'
#  BatchNormalization)                                                ]
#
#  block_6_expand_relu_DCNN_B  (None, 28, 28, 192)          0         ['block_6_expand_BN_DCNN_B[0][
#   (ReLU)                                                            0]']
#
#  block_6_pad_DCNN_B (ZeroPa  (None, 29, 29, 192)          0         ['block_6_expand_relu_DCNN_B[0
#  dding2D)                                                           ][0]']
#
#  block_6_depthwise_DCNN_B (  (None, 14, 14, 192)          1728      ['block_6_pad_DCNN_B[0][0]']
#  DepthwiseConv2D)
#
#  block_6_depthwise_BN_DCNN_  (None, 14, 14, 192)          768       ['block_6_depthwise_DCNN_B[0][
#  B (BatchNormalization)                                             0]']
#
#  block_6_depthwise_relu_DCN  (None, 14, 14, 192)          0         ['block_6_depthwise_BN_DCNN_B[
#  N_B (ReLU)                                                         0][0]']
#
#  block_6_project_DCNN_B (Co  (None, 14, 14, 64)           12288     ['block_6_depthwise_relu_DCNN_
#  nv2D)                                                              B[0][0]']
#
#  block_6_project_BN_DCNN_B   (None, 14, 14, 64)           256       ['block_6_project_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block_7_expand_DCNN_B (Con  (None, 14, 14, 384)          24576     ['block_6_project_BN_DCNN_B[0]
#  v2D)                                                               [0]']
#
#  block_7_expand_BN_DCNN_B (  (None, 14, 14, 384)          1536      ['block_7_expand_DCNN_B[0][0]'
#  BatchNormalization)                                                ]
#
#  block_7_expand_relu_DCNN_B  (None, 14, 14, 384)          0         ['block_7_expand_BN_DCNN_B[0][
#   (ReLU)                                                            0]']
#
#  block_7_depthwise_DCNN_B (  (None, 14, 14, 384)          3456      ['block_7_expand_relu_DCNN_B[0
#  DepthwiseConv2D)                                                   ][0]']
#
#  block_7_depthwise_BN_DCNN_  (None, 14, 14, 384)          1536      ['block_7_depthwise_DCNN_B[0][
#  B (BatchNormalization)                                             0]']
#
#  block_7_depthwise_relu_DCN  (None, 14, 14, 384)          0         ['block_7_depthwise_BN_DCNN_B[
#  N_B (ReLU)                                                         0][0]']
#
#  block_7_project_DCNN_B (Co  (None, 14, 14, 64)           24576     ['block_7_depthwise_relu_DCNN_
#  nv2D)                                                              B[0][0]']
#
#  block_7_project_BN_DCNN_B   (None, 14, 14, 64)           256       ['block_7_project_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block_7_add_DCNN_B (Add)    (None, 14, 14, 64)           0         ['block_6_project_BN_DCNN_B[0]
#                                                                     [0]',
#                                                                      'block_7_project_BN_DCNN_B[0]
#                                                                     [0]']
#
#  block_8_expand_DCNN_B (Con  (None, 14, 14, 384)          24576     ['block_7_add_DCNN_B[0][0]']
#  v2D)
#
#  block_8_expand_BN_DCNN_B (  (None, 14, 14, 384)          1536      ['block_8_expand_DCNN_B[0][0]'
#  BatchNormalization)                                                ]
#
#  block_8_expand_relu_DCNN_B  (None, 14, 14, 384)          0         ['block_8_expand_BN_DCNN_B[0][
#   (ReLU)                                                            0]']
#
#  block_8_depthwise_DCNN_B (  (None, 14, 14, 384)          3456      ['block_8_expand_relu_DCNN_B[0
#  DepthwiseConv2D)                                                   ][0]']
#
#  block_8_depthwise_BN_DCNN_  (None, 14, 14, 384)          1536      ['block_8_depthwise_DCNN_B[0][
#  B (BatchNormalization)                                             0]']
#
#  block_8_depthwise_relu_DCN  (None, 14, 14, 384)          0         ['block_8_depthwise_BN_DCNN_B[
#  N_B (ReLU)                                                         0][0]']
#
#  block_8_project_DCNN_B (Co  (None, 14, 14, 64)           24576     ['block_8_depthwise_relu_DCNN_
#  nv2D)                                                              B[0][0]']
#
#  block_8_project_BN_DCNN_B   (None, 14, 14, 64)           256       ['block_8_project_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block_8_add_DCNN_B (Add)    (None, 14, 14, 64)           0         ['block_7_add_DCNN_B[0][0]',
#                                                                      'block_8_project_BN_DCNN_B[0]
#                                                                     [0]']
#
#  block_9_expand_DCNN_B (Con  (None, 14, 14, 384)          24576     ['block_8_add_DCNN_B[0][0]']
#  v2D)
#
#  block_9_expand_BN_DCNN_B (  (None, 14, 14, 384)          1536      ['block_9_expand_DCNN_B[0][0]'
#  BatchNormalization)                                                ]
#
#  block_9_expand_relu_DCNN_B  (None, 14, 14, 384)          0         ['block_9_expand_BN_DCNN_B[0][
#   (ReLU)                                                            0]']
#
#  block_9_depthwise_DCNN_B (  (None, 14, 14, 384)          3456      ['block_9_expand_relu_DCNN_B[0
#  DepthwiseConv2D)                                                   ][0]']
#
#  block_9_depthwise_BN_DCNN_  (None, 14, 14, 384)          1536      ['block_9_depthwise_DCNN_B[0][
#  B (BatchNormalization)                                             0]']
#
#  block_9_depthwise_relu_DCN  (None, 14, 14, 384)          0         ['block_9_depthwise_BN_DCNN_B[
#  N_B (ReLU)                                                         0][0]']
#
#  block_9_project_DCNN_B (Co  (None, 14, 14, 64)           24576     ['block_9_depthwise_relu_DCNN_
#  nv2D)                                                              B[0][0]']
#
#  block_9_project_BN_DCNN_B   (None, 14, 14, 64)           256       ['block_9_project_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block_9_add_DCNN_B (Add)    (None, 14, 14, 64)           0         ['block_8_add_DCNN_B[0][0]',
#                                                                      'block_9_project_BN_DCNN_B[0]
#                                                                     [0]']
#
#  block_10_expand_DCNN_B (Co  (None, 14, 14, 384)          24576     ['block_9_add_DCNN_B[0][0]']
#  nv2D)
#
#  block_10_expand_BN_DCNN_B   (None, 14, 14, 384)          1536      ['block_10_expand_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block_10_expand_relu_DCNN_  (None, 14, 14, 384)          0         ['block_10_expand_BN_DCNN_B[0]
#  B (ReLU)                                                           [0]']
#
#  block_10_depthwise_DCNN_B   (None, 14, 14, 384)          3456      ['block_10_expand_relu_DCNN_B[
#  (DepthwiseConv2D)                                                  0][0]']
#
#  block_10_depthwise_BN_DCNN  (None, 14, 14, 384)          1536      ['block_10_depthwise_DCNN_B[0]
#  _B (BatchNormalization)                                            [0]']
#
#  block_10_depthwise_relu_DC  (None, 14, 14, 384)          0         ['block_10_depthwise_BN_DCNN_B
#  NN_B (ReLU)                                                        [0][0]']
#
#  block_10_project_DCNN_B (C  (None, 14, 14, 96)           36864     ['block_10_depthwise_relu_DCNN
#  onv2D)                                                             _B[0][0]']
#
#  block_10_project_BN_DCNN_B  (None, 14, 14, 96)           384       ['block_10_project_DCNN_B[0][0
#   (BatchNormalization)                                              ]']
#
#  block_11_expand_DCNN_B (Co  (None, 14, 14, 576)          55296     ['block_10_project_BN_DCNN_B[0
#  nv2D)                                                              ][0]']
#
#  block_11_expand_BN_DCNN_B   (None, 14, 14, 576)          2304      ['block_11_expand_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block_11_expand_relu_DCNN_  (None, 14, 14, 576)          0         ['block_11_expand_BN_DCNN_B[0]
#  B (ReLU)                                                           [0]']
#
#  block_11_depthwise_DCNN_B   (None, 14, 14, 576)          5184      ['block_11_expand_relu_DCNN_B[
#  (DepthwiseConv2D)                                                  0][0]']
#
#  block_11_depthwise_BN_DCNN  (None, 14, 14, 576)          2304      ['block_11_depthwise_DCNN_B[0]
#  _B (BatchNormalization)                                            [0]']
#
#  block_11_depthwise_relu_DC  (None, 14, 14, 576)          0         ['block_11_depthwise_BN_DCNN_B
#  NN_B (ReLU)                                                        [0][0]']
#
#  block_11_project_DCNN_B (C  (None, 14, 14, 96)           55296     ['block_11_depthwise_relu_DCNN
#  onv2D)                                                             _B[0][0]']
#
#  block_11_project_BN_DCNN_B  (None, 14, 14, 96)           384       ['block_11_project_DCNN_B[0][0
#   (BatchNormalization)                                              ]']
#
#  block_11_add_DCNN_B (Add)   (None, 14, 14, 96)           0         ['block_10_project_BN_DCNN_B[0
#                                                                     ][0]',
#                                                                      'block_11_project_BN_DCNN_B[0
#                                                                     ][0]']
#
#  block_12_expand_DCNN_B (Co  (None, 14, 14, 576)          55296     ['block_11_add_DCNN_B[0][0]']
#  nv2D)
#
#  block_12_expand_BN_DCNN_B   (None, 14, 14, 576)          2304      ['block_12_expand_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block_12_expand_relu_DCNN_  (None, 14, 14, 576)          0         ['block_12_expand_BN_DCNN_B[0]
#  B (ReLU)                                                           [0]']
#
#  block_12_depthwise_DCNN_B   (None, 14, 14, 576)          5184      ['block_12_expand_relu_DCNN_B[
#  (DepthwiseConv2D)                                                  0][0]']
#
#  block_12_depthwise_BN_DCNN  (None, 14, 14, 576)          2304      ['block_12_depthwise_DCNN_B[0]
#  _B (BatchNormalization)                                            [0]']
#
#  block_12_depthwise_relu_DC  (None, 14, 14, 576)          0         ['block_12_depthwise_BN_DCNN_B
#  NN_B (ReLU)                                                        [0][0]']
#
#  block_12_project_DCNN_B (C  (None, 14, 14, 96)           55296     ['block_12_depthwise_relu_DCNN
#  onv2D)                                                             _B[0][0]']
#
#  block_12_project_BN_DCNN_B  (None, 14, 14, 96)           384       ['block_12_project_DCNN_B[0][0
#   (BatchNormalization)                                              ]']
#
#  block_12_add_DCNN_B (Add)   (None, 14, 14, 96)           0         ['block_11_add_DCNN_B[0][0]',
#                                                                      'block_12_project_BN_DCNN_B[0
#                                                                     ][0]']
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 192)            1179840   ['block_12_add_DCNN_B[0][0]']
#
#  average_pooling2d_1 (Avera  (None, 7, 7, 192)            0         ['conv2d_1[0][0]']
#  gePooling2D)
#
#  alpha_dropout_1 (AlphaDrop  (None, 7, 7, 192)            0         ['average_pooling2d_1[0][0]']
#  out)
#
# ==================================================================================================
# Total params: 1738496 (6.63 MB)
# Trainable params: 1179840 (4.50 MB)
# Non-trainable params: 558656 (2.13 MB)
# __________________________________________________________________________________________________
#  successfully built!

# %%
# Model
#ResNet50V2

builder_c = DCNN_C + '_builder'

#TRANSFER LEARNING
def builder_c(model_input):
    builder_c = trainable_model_c(weights='imagenet', 
                                    include_top=False, 
                                    input_tensor = model_input)

#PARTIAL LAYER FREEZING
    for layer in builder_c.layers:
        layer.trainable = False
        
    for layer in builder_c.layers:
        layer._name = layer.name + '_' + DCNN_C
        
    for BatchNormalization in builder_c.layers:
        BatchNormalization.trainable = False
    
    x = builder_c.layers[-117].output  
    
 #AUXILIARY FUSING LAYER (AuxFL)   
    x = Conv2D(192, 6, padding='valid', activation='selu', kernel_initializer='lecun_normal')(x)
    x = AveragePooling2D(3, 3)(x)
    x = AlphaDropout(0.2)(x)

    dcnn_c = Model(inputs=builder_c.input, outputs=x, name=DCNN_C)
    return dcnn_c

#INITIALIZE THE MODEL
dcnn_c = builder_c(model_input)

#PLOT THE MODEL STRUCTURE
print("PLEASE CHECK THE ENTIRE MODEL UP TO THE END")

dcnn_c.summary()

print("successfully built!")
# Out:
# PLEASE CHECK THE ENTIRE MODEL UP TO THE END
# Model: "DCNN_C"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1_DCNN_A_DCNN_B_DCNN  [(None, 224, 224, 3)]        0         []
#  _C (InputLayer)
#
#  conv1_pad_DCNN_C (ZeroPadd  (None, 230, 230, 3)          0         ['input_1_DCNN_A_DCNN_B_DCNN_C
#  ing2D)                                                             [0][0]']
#
#  conv1_conv_DCNN_C (Conv2D)  (None, 112, 112, 64)         9472      ['conv1_pad_DCNN_C[0][0]']
#
#  pool1_pad_DCNN_C (ZeroPadd  (None, 114, 114, 64)         0         ['conv1_conv_DCNN_C[0][0]']
#  ing2D)
#
#  pool1_pool_DCNN_C (MaxPool  (None, 56, 56, 64)           0         ['pool1_pad_DCNN_C[0][0]']
#  ing2D)
#
#  conv2_block1_preact_bn_DCN  (None, 56, 56, 64)           256       ['pool1_pool_DCNN_C[0][0]']
#  N_C (BatchNormalization)
#
#  conv2_block1_preact_relu_D  (None, 56, 56, 64)           0         ['conv2_block1_preact_bn_DCNN_
#  CNN_C (Activation)                                                 C[0][0]']
#
#  conv2_block1_1_conv_DCNN_C  (None, 56, 56, 64)           4096      ['conv2_block1_preact_relu_DCN
#   (Conv2D)                                                          N_C[0][0]']
#
#  conv2_block1_1_bn_DCNN_C (  (None, 56, 56, 64)           256       ['conv2_block1_1_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  conv2_block1_1_relu_DCNN_C  (None, 56, 56, 64)           0         ['conv2_block1_1_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  conv2_block1_2_pad_DCNN_C   (None, 58, 58, 64)           0         ['conv2_block1_1_relu_DCNN_C[0
#  (ZeroPadding2D)                                                    ][0]']
#
#  conv2_block1_2_conv_DCNN_C  (None, 56, 56, 64)           36864     ['conv2_block1_2_pad_DCNN_C[0]
#   (Conv2D)                                                          [0]']
#
#  conv2_block1_2_bn_DCNN_C (  (None, 56, 56, 64)           256       ['conv2_block1_2_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  conv2_block1_2_relu_DCNN_C  (None, 56, 56, 64)           0         ['conv2_block1_2_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  conv2_block1_0_conv_DCNN_C  (None, 56, 56, 256)          16640     ['conv2_block1_preact_relu_DCN
#   (Conv2D)                                                          N_C[0][0]']
#
#  conv2_block1_3_conv_DCNN_C  (None, 56, 56, 256)          16640     ['conv2_block1_2_relu_DCNN_C[0
#   (Conv2D)                                                          ][0]']
#
#  conv2_block1_out_DCNN_C (A  (None, 56, 56, 256)          0         ['conv2_block1_0_conv_DCNN_C[0
#  dd)                                                                ][0]',
#                                                                      'conv2_block1_3_conv_DCNN_C[0
#                                                                     ][0]']
#
#  conv2_block2_preact_bn_DCN  (None, 56, 56, 256)          1024      ['conv2_block1_out_DCNN_C[0][0
#  N_C (BatchNormalization)                                           ]']
#
#  conv2_block2_preact_relu_D  (None, 56, 56, 256)          0         ['conv2_block2_preact_bn_DCNN_
#  CNN_C (Activation)                                                 C[0][0]']
#
#  conv2_block2_1_conv_DCNN_C  (None, 56, 56, 64)           16384     ['conv2_block2_preact_relu_DCN
#   (Conv2D)                                                          N_C[0][0]']
#
#  conv2_block2_1_bn_DCNN_C (  (None, 56, 56, 64)           256       ['conv2_block2_1_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  conv2_block2_1_relu_DCNN_C  (None, 56, 56, 64)           0         ['conv2_block2_1_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  conv2_block2_2_pad_DCNN_C   (None, 58, 58, 64)           0         ['conv2_block2_1_relu_DCNN_C[0
#  (ZeroPadding2D)                                                    ][0]']
#
#  conv2_block2_2_conv_DCNN_C  (None, 56, 56, 64)           36864     ['conv2_block2_2_pad_DCNN_C[0]
#   (Conv2D)                                                          [0]']
#
#  conv2_block2_2_bn_DCNN_C (  (None, 56, 56, 64)           256       ['conv2_block2_2_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  conv2_block2_2_relu_DCNN_C  (None, 56, 56, 64)           0         ['conv2_block2_2_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  conv2_block2_3_conv_DCNN_C  (None, 56, 56, 256)          16640     ['conv2_block2_2_relu_DCNN_C[0
#   (Conv2D)                                                          ][0]']
#
#  conv2_block2_out_DCNN_C (A  (None, 56, 56, 256)          0         ['conv2_block1_out_DCNN_C[0][0
#  dd)                                                                ]',
#                                                                      'conv2_block2_3_conv_DCNN_C[0
#                                                                     ][0]']
#
#  conv2_block3_preact_bn_DCN  (None, 56, 56, 256)          1024      ['conv2_block2_out_DCNN_C[0][0
#  N_C (BatchNormalization)                                           ]']
#
#  conv2_block3_preact_relu_D  (None, 56, 56, 256)          0         ['conv2_block3_preact_bn_DCNN_
#  CNN_C (Activation)                                                 C[0][0]']
#
#  conv2_block3_1_conv_DCNN_C  (None, 56, 56, 64)           16384     ['conv2_block3_preact_relu_DCN
#   (Conv2D)                                                          N_C[0][0]']
#
#  conv2_block3_1_bn_DCNN_C (  (None, 56, 56, 64)           256       ['conv2_block3_1_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  conv2_block3_1_relu_DCNN_C  (None, 56, 56, 64)           0         ['conv2_block3_1_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  conv2_block3_2_pad_DCNN_C   (None, 58, 58, 64)           0         ['conv2_block3_1_relu_DCNN_C[0
#  (ZeroPadding2D)                                                    ][0]']
#
#  conv2_block3_2_conv_DCNN_C  (None, 28, 28, 64)           36864     ['conv2_block3_2_pad_DCNN_C[0]
#   (Conv2D)                                                          [0]']
#
#  conv2_block3_2_bn_DCNN_C (  (None, 28, 28, 64)           256       ['conv2_block3_2_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  conv2_block3_2_relu_DCNN_C  (None, 28, 28, 64)           0         ['conv2_block3_2_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  max_pooling2d_DCNN_C (MaxP  (None, 28, 28, 256)          0         ['conv2_block2_out_DCNN_C[0][0
#  ooling2D)                                                          ]']
#
#  conv2_block3_3_conv_DCNN_C  (None, 28, 28, 256)          16640     ['conv2_block3_2_relu_DCNN_C[0
#   (Conv2D)                                                          ][0]']
#
#  conv2_block3_out_DCNN_C (A  (None, 28, 28, 256)          0         ['max_pooling2d_DCNN_C[0][0]',
#  dd)                                                                 'conv2_block3_3_conv_DCNN_C[0
#                                                                     ][0]']
#
#  conv3_block1_preact_bn_DCN  (None, 28, 28, 256)          1024      ['conv2_block3_out_DCNN_C[0][0
#  N_C (BatchNormalization)                                           ]']
#
#  conv3_block1_preact_relu_D  (None, 28, 28, 256)          0         ['conv3_block1_preact_bn_DCNN_
#  CNN_C (Activation)                                                 C[0][0]']
#
#  conv3_block1_1_conv_DCNN_C  (None, 28, 28, 128)          32768     ['conv3_block1_preact_relu_DCN
#   (Conv2D)                                                          N_C[0][0]']
#
#  conv3_block1_1_bn_DCNN_C (  (None, 28, 28, 128)          512       ['conv3_block1_1_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  conv3_block1_1_relu_DCNN_C  (None, 28, 28, 128)          0         ['conv3_block1_1_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  conv3_block1_2_pad_DCNN_C   (None, 30, 30, 128)          0         ['conv3_block1_1_relu_DCNN_C[0
#  (ZeroPadding2D)                                                    ][0]']
#
#  conv3_block1_2_conv_DCNN_C  (None, 28, 28, 128)          147456    ['conv3_block1_2_pad_DCNN_C[0]
#   (Conv2D)                                                          [0]']
#
#  conv3_block1_2_bn_DCNN_C (  (None, 28, 28, 128)          512       ['conv3_block1_2_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  conv3_block1_2_relu_DCNN_C  (None, 28, 28, 128)          0         ['conv3_block1_2_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  conv3_block1_0_conv_DCNN_C  (None, 28, 28, 512)          131584    ['conv3_block1_preact_relu_DCN
#   (Conv2D)                                                          N_C[0][0]']
#
#  conv3_block1_3_conv_DCNN_C  (None, 28, 28, 512)          66048     ['conv3_block1_2_relu_DCNN_C[0
#   (Conv2D)                                                          ][0]']
#
#  conv3_block1_out_DCNN_C (A  (None, 28, 28, 512)          0         ['conv3_block1_0_conv_DCNN_C[0
#  dd)                                                                ][0]',
#                                                                      'conv3_block1_3_conv_DCNN_C[0
#                                                                     ][0]']
#
#  conv3_block2_preact_bn_DCN  (None, 28, 28, 512)          2048      ['conv3_block1_out_DCNN_C[0][0
#  N_C (BatchNormalization)                                           ]']
#
#  conv3_block2_preact_relu_D  (None, 28, 28, 512)          0         ['conv3_block2_preact_bn_DCNN_
#  CNN_C (Activation)                                                 C[0][0]']
#
#  conv3_block2_1_conv_DCNN_C  (None, 28, 28, 128)          65536     ['conv3_block2_preact_relu_DCN
#   (Conv2D)                                                          N_C[0][0]']
#
#  conv3_block2_1_bn_DCNN_C (  (None, 28, 28, 128)          512       ['conv3_block2_1_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  conv3_block2_1_relu_DCNN_C  (None, 28, 28, 128)          0         ['conv3_block2_1_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  conv3_block2_2_pad_DCNN_C   (None, 30, 30, 128)          0         ['conv3_block2_1_relu_DCNN_C[0
#  (ZeroPadding2D)                                                    ][0]']
#
#  conv3_block2_2_conv_DCNN_C  (None, 28, 28, 128)          147456    ['conv3_block2_2_pad_DCNN_C[0]
#   (Conv2D)                                                          [0]']
#
#  conv3_block2_2_bn_DCNN_C (  (None, 28, 28, 128)          512       ['conv3_block2_2_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  conv3_block2_2_relu_DCNN_C  (None, 28, 28, 128)          0         ['conv3_block2_2_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  conv3_block2_3_conv_DCNN_C  (None, 28, 28, 512)          66048     ['conv3_block2_2_relu_DCNN_C[0
#   (Conv2D)                                                          ][0]']
#
#  conv3_block2_out_DCNN_C (A  (None, 28, 28, 512)          0         ['conv3_block1_out_DCNN_C[0][0
#  dd)                                                                ]',
#                                                                      'conv3_block2_3_conv_DCNN_C[0
#                                                                     ][0]']
#
#  conv3_block3_preact_bn_DCN  (None, 28, 28, 512)          2048      ['conv3_block2_out_DCNN_C[0][0
#  N_C (BatchNormalization)                                           ]']
#
#  conv3_block3_preact_relu_D  (None, 28, 28, 512)          0         ['conv3_block3_preact_bn_DCNN_
#  CNN_C (Activation)                                                 C[0][0]']
#
#  conv3_block3_1_conv_DCNN_C  (None, 28, 28, 128)          65536     ['conv3_block3_preact_relu_DCN
#   (Conv2D)                                                          N_C[0][0]']
#
#  conv3_block3_1_bn_DCNN_C (  (None, 28, 28, 128)          512       ['conv3_block3_1_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  conv3_block3_1_relu_DCNN_C  (None, 28, 28, 128)          0         ['conv3_block3_1_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  conv3_block3_2_pad_DCNN_C   (None, 30, 30, 128)          0         ['conv3_block3_1_relu_DCNN_C[0
#  (ZeroPadding2D)                                                    ][0]']
#
#  conv3_block3_2_conv_DCNN_C  (None, 28, 28, 128)          147456    ['conv3_block3_2_pad_DCNN_C[0]
#   (Conv2D)                                                          [0]']
#
#  conv3_block3_2_bn_DCNN_C (  (None, 28, 28, 128)          512       ['conv3_block3_2_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  conv3_block3_2_relu_DCNN_C  (None, 28, 28, 128)          0         ['conv3_block3_2_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  conv3_block3_3_conv_DCNN_C  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu_DCNN_C[0
#   (Conv2D)                                                          ][0]']
#
#  conv3_block3_out_DCNN_C (A  (None, 28, 28, 512)          0         ['conv3_block2_out_DCNN_C[0][0
#  dd)                                                                ]',
#                                                                      'conv3_block3_3_conv_DCNN_C[0
#                                                                     ][0]']
#
#  conv2d_2 (Conv2D)           (None, 23, 23, 192)          3539136   ['conv3_block3_out_DCNN_C[0][0
#                                                                     ]']
#
#  average_pooling2d_2 (Avera  (None, 7, 7, 192)            0         ['conv2d_2[0][0]']
#  gePooling2D)
#
#  alpha_dropout_2 (AlphaDrop  (None, 7, 7, 192)            0         ['average_pooling2d_2[0][0]']
#  out)
#
# ==================================================================================================
# Total params: 4710592 (17.97 MB)
# Trainable params: 3539136 (13.50 MB)
# Non-trainable params: 1171456 (4.47 MB)
# __________________________________________________________________________________________________
# successfully built!

# %%
#RE-INITIALIZE FOR FUSION
dcnn_a = builder_a(model_input)
dcnn_b = builder_b(model_input)
dcnn_c = builder_c(model_input)

print("Accomplished Pre-training and ready for fusion")
# Out:
# Accomplished Pre-training and ready for fusion

# %%
#FUSE THE MODELS INTO A SINGLE PIPELINE

models = [dcnn_a, 
          dcnn_b,
          dcnn_c]

print("Fusion success!")
print("Ready to connect with its ending layers!")
# Out:
# Fusion success!
# Ready to connect with its ending layers!

# %%
#Build the Fusion Residual Block (FuRB)
def mfurecnn_builder(models, model_input):
    outputs = [m.output for m in models]
    
#INITIAL FUSION LAYER
    y = Add(name='InitialFusionLayer')(outputs)
    
#FuRB
    y_bn1 = BatchNormalization()(y)
    y_selu1 = tf.keras.activations.selu(y_bn1)
    y_conv1 = Conv2D(192, 1, kernel_initializer='lecun_normal')(y_selu1)
    y_bn2 = BatchNormalization()(y_conv1)
    y_selu2 = tf.keras.activations.selu(y_bn2)
    y_conv2 = Conv2D(192, 1, kernel_initializer='lecun_normal')(y_selu2)
    
    y_merge = Add(name='FuRB')([y, y_conv2])
    
#FINE-TUNING
    y = GlobalAveragePooling2D()(y_merge)
    y = AlphaDropout(0.5)(y)
    prediction = Dense(num_classes,activation='softmax', name='Softmax_Classifier' + architecture)(y)
    model = Model(model_input, prediction, name=architecture)
    return model

#Istantitate the model and report the summary
mfurecnn = mfurecnn_builder(models, model_input)

print()
print()
print("PLEASE CHECK THE MODEL UP TO THE END")
print()
print()
print()

mfurecnn.summary()
print("Complete and ready for compilation and training!")
# Out:
# PLEASE CHECK THE MODEL UP TO THE END
#
#
#
# Model: "MFuReCNN_alpha_do_Learning_rate_0.01"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1_DCNN_A_DCNN_B_DCNN  [(None, 224, 224, 3)]        0         []
#  _C_DCNN_A_DCNN_B_DCNN_C (I
#  nputLayer)
#
#  rescaling_2_DCNN_A (Rescal  (None, 224, 224, 3)          0         ['input_1_DCNN_A_DCNN_B_DCNN_C
#  ing)                                                               _DCNN_A_DCNN_B_DCNN_C[0][0]']
#
#  normalization_1_DCNN_A (No  (None, 224, 224, 3)          7         ['rescaling_2_DCNN_A[0][0]']
#  rmalization)
#
#  rescaling_3_DCNN_A (Rescal  (None, 224, 224, 3)          0         ['normalization_1_DCNN_A[0][0]
#  ing)                                                               ']
#
#  stem_conv_pad_DCNN_A (Zero  (None, 225, 225, 3)          0         ['rescaling_3_DCNN_A[0][0]']
#  Padding2D)
#
#  stem_conv_DCNN_A (Conv2D)   (None, 112, 112, 32)         864       ['stem_conv_pad_DCNN_A[0][0]']
#
#  stem_bn_DCNN_A (BatchNorma  (None, 112, 112, 32)         128       ['stem_conv_DCNN_A[0][0]']
#  lization)
#
#  stem_activation_DCNN_A (Ac  (None, 112, 112, 32)         0         ['stem_bn_DCNN_A[0][0]']
#  tivation)
#
#  block1a_dwconv_DCNN_A (Dep  (None, 112, 112, 32)         288       ['stem_activation_DCNN_A[0][0]
#  thwiseConv2D)                                                      ']
#
#  block1a_bn_DCNN_A (BatchNo  (None, 112, 112, 32)         128       ['block1a_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block1a_activation_DCNN_A   (None, 112, 112, 32)         0         ['block1a_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block1a_se_squeeze_DCNN_A   (None, 32)                   0         ['block1a_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block1a_se_reshape_DCNN_A   (None, 1, 1, 32)             0         ['block1a_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block1a_se_reduce_DCNN_A (  (None, 1, 1, 8)              264       ['block1a_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block1a_se_expand_DCNN_A (  (None, 1, 1, 32)             288       ['block1a_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block1a_se_excite_DCNN_A (  (None, 112, 112, 32)         0         ['block1a_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block1a_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block1a_project_conv_DCNN_  (None, 112, 112, 16)         512       ['block1a_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block1a_project_bn_DCNN_A   (None, 112, 112, 16)         64        ['block1a_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block2a_expand_conv_DCNN_A  (None, 112, 112, 96)         1536      ['block1a_project_bn_DCNN_A[0]
#   (Conv2D)                                                          [0]']
#
#  block2a_expand_bn_DCNN_A (  (None, 112, 112, 96)         384       ['block2a_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block2a_expand_activation_  (None, 112, 112, 96)         0         ['block2a_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block2a_dwconv_pad_DCNN_A   (None, 113, 113, 96)         0         ['block2a_expand_activation_DC
#  (ZeroPadding2D)                                                    NN_A[0][0]']
#
#  block2a_dwconv_DCNN_A (Dep  (None, 56, 56, 96)           864       ['block2a_dwconv_pad_DCNN_A[0]
#  thwiseConv2D)                                                      [0]']
#
#  block2a_bn_DCNN_A (BatchNo  (None, 56, 56, 96)           384       ['block2a_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block2a_activation_DCNN_A   (None, 56, 56, 96)           0         ['block2a_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block2a_se_squeeze_DCNN_A   (None, 96)                   0         ['block2a_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block2a_se_reshape_DCNN_A   (None, 1, 1, 96)             0         ['block2a_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block2a_se_reduce_DCNN_A (  (None, 1, 1, 4)              388       ['block2a_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block2a_se_expand_DCNN_A (  (None, 1, 1, 96)             480       ['block2a_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block2a_se_excite_DCNN_A (  (None, 56, 56, 96)           0         ['block2a_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block2a_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block2a_project_conv_DCNN_  (None, 56, 56, 24)           2304      ['block2a_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block2a_project_bn_DCNN_A   (None, 56, 56, 24)           96        ['block2a_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block2b_expand_conv_DCNN_A  (None, 56, 56, 144)          3456      ['block2a_project_bn_DCNN_A[0]
#   (Conv2D)                                                          [0]']
#
#  block2b_expand_bn_DCNN_A (  (None, 56, 56, 144)          576       ['block2b_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block2b_expand_activation_  (None, 56, 56, 144)          0         ['block2b_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block2b_dwconv_DCNN_A (Dep  (None, 56, 56, 144)          1296      ['block2b_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block2b_bn_DCNN_A (BatchNo  (None, 56, 56, 144)          576       ['block2b_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block2b_activation_DCNN_A   (None, 56, 56, 144)          0         ['block2b_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block2b_se_squeeze_DCNN_A   (None, 144)                  0         ['block2b_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block2b_se_reshape_DCNN_A   (None, 1, 1, 144)            0         ['block2b_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block2b_se_reduce_DCNN_A (  (None, 1, 1, 6)              870       ['block2b_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block2b_se_expand_DCNN_A (  (None, 1, 1, 144)            1008      ['block2b_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block2b_se_excite_DCNN_A (  (None, 56, 56, 144)          0         ['block2b_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block2b_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block2b_project_conv_DCNN_  (None, 56, 56, 24)           3456      ['block2b_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block2b_project_bn_DCNN_A   (None, 56, 56, 24)           96        ['block2b_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block2b_drop_DCNN_A (Dropo  (None, 56, 56, 24)           0         ['block2b_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block2b_add_DCNN_A (Add)    (None, 56, 56, 24)           0         ['block2b_drop_DCNN_A[0][0]',
#                                                                      'block2a_project_bn_DCNN_A[0]
#                                                                     [0]']
#
#  block3a_expand_conv_DCNN_A  (None, 56, 56, 144)          3456      ['block2b_add_DCNN_A[0][0]']
#   (Conv2D)
#
#  block3a_expand_bn_DCNN_A (  (None, 56, 56, 144)          576       ['block3a_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block3a_expand_activation_  (None, 56, 56, 144)          0         ['block3a_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block3a_dwconv_pad_DCNN_A   (None, 59, 59, 144)          0         ['block3a_expand_activation_DC
#  (ZeroPadding2D)                                                    NN_A[0][0]']
#
#  block3a_dwconv_DCNN_A (Dep  (None, 28, 28, 144)          3600      ['block3a_dwconv_pad_DCNN_A[0]
#  thwiseConv2D)                                                      [0]']
#
#  block3a_bn_DCNN_A (BatchNo  (None, 28, 28, 144)          576       ['block3a_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block3a_activation_DCNN_A   (None, 28, 28, 144)          0         ['block3a_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block3a_se_squeeze_DCNN_A   (None, 144)                  0         ['block3a_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block3a_se_reshape_DCNN_A   (None, 1, 1, 144)            0         ['block3a_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block3a_se_reduce_DCNN_A (  (None, 1, 1, 6)              870       ['block3a_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block3a_se_expand_DCNN_A (  (None, 1, 1, 144)            1008      ['block3a_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block3a_se_excite_DCNN_A (  (None, 28, 28, 144)          0         ['block3a_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block3a_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block3a_project_conv_DCNN_  (None, 28, 28, 40)           5760      ['block3a_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block3a_project_bn_DCNN_A   (None, 28, 28, 40)           160       ['block3a_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block3b_expand_conv_DCNN_A  (None, 28, 28, 240)          9600      ['block3a_project_bn_DCNN_A[0]
#   (Conv2D)                                                          [0]']
#
#  block3b_expand_bn_DCNN_A (  (None, 28, 28, 240)          960       ['block3b_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block3b_expand_activation_  (None, 28, 28, 240)          0         ['block3b_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block3b_dwconv_DCNN_A (Dep  (None, 28, 28, 240)          6000      ['block3b_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block3b_bn_DCNN_A (BatchNo  (None, 28, 28, 240)          960       ['block3b_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block3b_activation_DCNN_A   (None, 28, 28, 240)          0         ['block3b_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block3b_se_squeeze_DCNN_A   (None, 240)                  0         ['block3b_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block3b_se_reshape_DCNN_A   (None, 1, 1, 240)            0         ['block3b_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block3b_se_reduce_DCNN_A (  (None, 1, 1, 10)             2410      ['block3b_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block3b_se_expand_DCNN_A (  (None, 1, 1, 240)            2640      ['block3b_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block3b_se_excite_DCNN_A (  (None, 28, 28, 240)          0         ['block3b_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block3b_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block3b_project_conv_DCNN_  (None, 28, 28, 40)           9600      ['block3b_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block3b_project_bn_DCNN_A   (None, 28, 28, 40)           160       ['block3b_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block3b_drop_DCNN_A (Dropo  (None, 28, 28, 40)           0         ['block3b_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block3b_add_DCNN_A (Add)    (None, 28, 28, 40)           0         ['block3b_drop_DCNN_A[0][0]',
#                                                                      'block3a_project_bn_DCNN_A[0]
#                                                                     [0]']
#
#  block4a_expand_conv_DCNN_A  (None, 28, 28, 240)          9600      ['block3b_add_DCNN_A[0][0]']
#   (Conv2D)
#
#  block4a_expand_bn_DCNN_A (  (None, 28, 28, 240)          960       ['block4a_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block4a_expand_activation_  (None, 28, 28, 240)          0         ['block4a_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block4a_dwconv_pad_DCNN_A   (None, 29, 29, 240)          0         ['block4a_expand_activation_DC
#  (ZeroPadding2D)                                                    NN_A[0][0]']
#
#  block4a_dwconv_DCNN_A (Dep  (None, 14, 14, 240)          2160      ['block4a_dwconv_pad_DCNN_A[0]
#  thwiseConv2D)                                                      [0]']
#
#  block4a_bn_DCNN_A (BatchNo  (None, 14, 14, 240)          960       ['block4a_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block4a_activation_DCNN_A   (None, 14, 14, 240)          0         ['block4a_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block4a_se_squeeze_DCNN_A   (None, 240)                  0         ['block4a_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block4a_se_reshape_DCNN_A   (None, 1, 1, 240)            0         ['block4a_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block4a_se_reduce_DCNN_A (  (None, 1, 1, 10)             2410      ['block4a_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block4a_se_expand_DCNN_A (  (None, 1, 1, 240)            2640      ['block4a_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block4a_se_excite_DCNN_A (  (None, 14, 14, 240)          0         ['block4a_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block4a_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block4a_project_conv_DCNN_  (None, 14, 14, 80)           19200     ['block4a_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block4a_project_bn_DCNN_A   (None, 14, 14, 80)           320       ['block4a_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block4b_expand_conv_DCNN_A  (None, 14, 14, 480)          38400     ['block4a_project_bn_DCNN_A[0]
#   (Conv2D)                                                          [0]']
#
#  block4b_expand_bn_DCNN_A (  (None, 14, 14, 480)          1920      ['block4b_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block4b_expand_activation_  (None, 14, 14, 480)          0         ['block4b_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block4b_dwconv_DCNN_A (Dep  (None, 14, 14, 480)          4320      ['block4b_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block4b_bn_DCNN_A (BatchNo  (None, 14, 14, 480)          1920      ['block4b_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block4b_activation_DCNN_A   (None, 14, 14, 480)          0         ['block4b_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block4b_se_squeeze_DCNN_A   (None, 480)                  0         ['block4b_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block4b_se_reshape_DCNN_A   (None, 1, 1, 480)            0         ['block4b_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block4b_se_reduce_DCNN_A (  (None, 1, 1, 20)             9620      ['block4b_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block4b_se_expand_DCNN_A (  (None, 1, 1, 480)            10080     ['block4b_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block4b_se_excite_DCNN_A (  (None, 14, 14, 480)          0         ['block4b_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block4b_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block4b_project_conv_DCNN_  (None, 14, 14, 80)           38400     ['block4b_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block4b_project_bn_DCNN_A   (None, 14, 14, 80)           320       ['block4b_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block4b_drop_DCNN_A (Dropo  (None, 14, 14, 80)           0         ['block4b_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block4b_add_DCNN_A (Add)    (None, 14, 14, 80)           0         ['block4b_drop_DCNN_A[0][0]',
#                                                                      'block4a_project_bn_DCNN_A[0]
#                                                                     [0]']
#
#  block4c_expand_conv_DCNN_A  (None, 14, 14, 480)          38400     ['block4b_add_DCNN_A[0][0]']
#   (Conv2D)
#
#  block4c_expand_bn_DCNN_A (  (None, 14, 14, 480)          1920      ['block4c_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block4c_expand_activation_  (None, 14, 14, 480)          0         ['block4c_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  Conv1_DCNN_B (Conv2D)       (None, 112, 112, 32)         864       ['input_1_DCNN_A_DCNN_B_DCNN_C
#                                                                     _DCNN_A_DCNN_B_DCNN_C[0][0]']
#
#  block4c_dwconv_DCNN_A (Dep  (None, 14, 14, 480)          4320      ['block4c_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  bn_Conv1_DCNN_B (BatchNorm  (None, 112, 112, 32)         128       ['Conv1_DCNN_B[0][0]']
#  alization)
#
#  block4c_bn_DCNN_A (BatchNo  (None, 14, 14, 480)          1920      ['block4c_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  Conv1_relu_DCNN_B (ReLU)    (None, 112, 112, 32)         0         ['bn_Conv1_DCNN_B[0][0]']
#
#  block4c_activation_DCNN_A   (None, 14, 14, 480)          0         ['block4c_bn_DCNN_A[0][0]']
#  (Activation)
#
#  expanded_conv_depthwise_DC  (None, 112, 112, 32)         288       ['Conv1_relu_DCNN_B[0][0]']
#  NN_B (DepthwiseConv2D)
#
#  block4c_se_squeeze_DCNN_A   (None, 480)                  0         ['block4c_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  expanded_conv_depthwise_BN  (None, 112, 112, 32)         128       ['expanded_conv_depthwise_DCNN
#  _DCNN_B (BatchNormalizatio                                         _B[0][0]']
#  n)
#
#  block4c_se_reshape_DCNN_A   (None, 1, 1, 480)            0         ['block4c_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  expanded_conv_depthwise_re  (None, 112, 112, 32)         0         ['expanded_conv_depthwise_BN_D
#  lu_DCNN_B (ReLU)                                                   CNN_B[0][0]']
#
#  block4c_se_reduce_DCNN_A (  (None, 1, 1, 20)             9620      ['block4c_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  expanded_conv_project_DCNN  (None, 112, 112, 16)         512       ['expanded_conv_depthwise_relu
#  _B (Conv2D)                                                        _DCNN_B[0][0]']
#
#  block4c_se_expand_DCNN_A (  (None, 1, 1, 480)            10080     ['block4c_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  expanded_conv_project_BN_D  (None, 112, 112, 16)         64        ['expanded_conv_project_DCNN_B
#  CNN_B (BatchNormalization)                                         [0][0]']
#
#  block4c_se_excite_DCNN_A (  (None, 14, 14, 480)          0         ['block4c_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block4c_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block_1_expand_DCNN_B (Con  (None, 112, 112, 96)         1536      ['expanded_conv_project_BN_DCN
#  v2D)                                                               N_B[0][0]']
#
#  block4c_project_conv_DCNN_  (None, 14, 14, 80)           38400     ['block4c_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block_1_expand_BN_DCNN_B (  (None, 112, 112, 96)         384       ['block_1_expand_DCNN_B[0][0]'
#  BatchNormalization)                                                ]
#
#  block4c_project_bn_DCNN_A   (None, 14, 14, 80)           320       ['block4c_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block_1_expand_relu_DCNN_B  (None, 112, 112, 96)         0         ['block_1_expand_BN_DCNN_B[0][
#   (ReLU)                                                            0]']
#
#  block4c_drop_DCNN_A (Dropo  (None, 14, 14, 80)           0         ['block4c_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block_1_pad_DCNN_B (ZeroPa  (None, 113, 113, 96)         0         ['block_1_expand_relu_DCNN_B[0
#  dding2D)                                                           ][0]']
#
#  block4c_add_DCNN_A (Add)    (None, 14, 14, 80)           0         ['block4c_drop_DCNN_A[0][0]',
#                                                                      'block4b_add_DCNN_A[0][0]']
#
#  block_1_depthwise_DCNN_B (  (None, 56, 56, 96)           864       ['block_1_pad_DCNN_B[0][0]']
#  DepthwiseConv2D)
#
#  block5a_expand_conv_DCNN_A  (None, 14, 14, 480)          38400     ['block4c_add_DCNN_A[0][0]']
#   (Conv2D)
#
#  block_1_depthwise_BN_DCNN_  (None, 56, 56, 96)           384       ['block_1_depthwise_DCNN_B[0][
#  B (BatchNormalization)                                             0]']
#
#  block5a_expand_bn_DCNN_A (  (None, 14, 14, 480)          1920      ['block5a_expand_conv_DCNN_A[0
#  BatchNormalization)                                                ][0]']
#
#  block_1_depthwise_relu_DCN  (None, 56, 56, 96)           0         ['block_1_depthwise_BN_DCNN_B[
#  N_B (ReLU)                                                         0][0]']
#
#  block5a_expand_activation_  (None, 14, 14, 480)          0         ['block5a_expand_bn_DCNN_A[0][
#  DCNN_A (Activation)                                                0]']
#
#  block_1_project_DCNN_B (Co  (None, 56, 56, 24)           2304      ['block_1_depthwise_relu_DCNN_
#  nv2D)                                                              B[0][0]']
#
#  block5a_dwconv_DCNN_A (Dep  (None, 14, 14, 480)          12000     ['block5a_expand_activation_DC
#  thwiseConv2D)                                                      NN_A[0][0]']
#
#  block_1_project_BN_DCNN_B   (None, 56, 56, 24)           96        ['block_1_project_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  block5a_bn_DCNN_A (BatchNo  (None, 14, 14, 480)          1920      ['block5a_dwconv_DCNN_A[0][0]'
#  rmalization)                                                       ]
#
#  block_2_expand_DCNN_B (Con  (None, 56, 56, 144)          3456      ['block_1_project_BN_DCNN_B[0]
#  v2D)                                                               [0]']
#
#  block5a_activation_DCNN_A   (None, 14, 14, 480)          0         ['block5a_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block_2_expand_BN_DCNN_B (  (None, 56, 56, 144)          576       ['block_2_expand_DCNN_B[0][0]'
#  BatchNormalization)                                                ]
#
#  block5a_se_squeeze_DCNN_A   (None, 480)                  0         ['block5a_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block_2_expand_relu_DCNN_B  (None, 56, 56, 144)          0         ['block_2_expand_BN_DCNN_B[0][
#   (ReLU)                                                            0]']
#
#  block5a_se_reshape_DCNN_A   (None, 1, 1, 480)            0         ['block5a_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block_2_depthwise_DCNN_B (  (None, 56, 56, 144)          1296      ['block_2_expand_relu_DCNN_B[0
#  DepthwiseConv2D)                                                   ][0]']
#
#  block5a_se_reduce_DCNN_A (  (None, 1, 1, 20)             9620      ['block5a_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block_2_depthwise_BN_DCNN_  (None, 56, 56, 144)          576       ['block_2_depthwise_DCNN_B[0][
#  B (BatchNormalization)                                             0]']
#
#  block5a_se_expand_DCNN_A (  (None, 1, 1, 480)            10080     ['block5a_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block_2_depthwise_relu_DCN  (None, 56, 56, 144)          0         ['block_2_depthwise_BN_DCNN_B[
#  N_B (ReLU)                                                         0][0]']
#
#  block5a_se_excite_DCNN_A (  (None, 14, 14, 480)          0         ['block5a_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
# ...
#
#  conv3_block3_preact_bn_DCN  (None, 28, 28, 512)          2048      ['conv3_block2_out_DCNN_C[0][0
#  N_C (BatchNormalization)                                           ]']
#
#  block6d_activation_DCNN_A   (None, 7, 7, 1152)           0         ['block6d_bn_DCNN_A[0][0]']
#  (Activation)
#
#  block_11_add_DCNN_B (Add)   (None, 14, 14, 96)           0         ['block_10_project_BN_DCNN_B[0
#                                                                     ][0]',
#                                                                      'block_11_project_BN_DCNN_B[0
#                                                                     ][0]']
#
#  conv3_block3_preact_relu_D  (None, 28, 28, 512)          0         ['conv3_block3_preact_bn_DCNN_
#  CNN_C (Activation)                                                 C[0][0]']
#
#  block6d_se_squeeze_DCNN_A   (None, 1152)                 0         ['block6d_activation_DCNN_A[0]
#  (GlobalAveragePooling2D)                                           [0]']
#
#  block_12_expand_DCNN_B (Co  (None, 14, 14, 576)          55296     ['block_11_add_DCNN_B[0][0]']
#  nv2D)
#
#  conv3_block3_1_conv_DCNN_C  (None, 28, 28, 128)          65536     ['conv3_block3_preact_relu_DCN
#   (Conv2D)                                                          N_C[0][0]']
#
#  block6d_se_reshape_DCNN_A   (None, 1, 1, 1152)           0         ['block6d_se_squeeze_DCNN_A[0]
#  (Reshape)                                                          [0]']
#
#  block_12_expand_BN_DCNN_B   (None, 14, 14, 576)          2304      ['block_12_expand_DCNN_B[0][0]
#  (BatchNormalization)                                               ']
#
#  conv3_block3_1_bn_DCNN_C (  (None, 28, 28, 128)          512       ['conv3_block3_1_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  block6d_se_reduce_DCNN_A (  (None, 1, 1, 48)             55344     ['block6d_se_reshape_DCNN_A[0]
#  Conv2D)                                                            [0]']
#
#  block_12_expand_relu_DCNN_  (None, 14, 14, 576)          0         ['block_12_expand_BN_DCNN_B[0]
#  B (ReLU)                                                           [0]']
#
#  conv3_block3_1_relu_DCNN_C  (None, 28, 28, 128)          0         ['conv3_block3_1_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  block6d_se_expand_DCNN_A (  (None, 1, 1, 1152)           56448     ['block6d_se_reduce_DCNN_A[0][
#  Conv2D)                                                            0]']
#
#  block_12_depthwise_DCNN_B   (None, 14, 14, 576)          5184      ['block_12_expand_relu_DCNN_B[
#  (DepthwiseConv2D)                                                  0][0]']
#
#  conv3_block3_2_pad_DCNN_C   (None, 30, 30, 128)          0         ['conv3_block3_1_relu_DCNN_C[0
#  (ZeroPadding2D)                                                    ][0]']
#
#  block6d_se_excite_DCNN_A (  (None, 7, 7, 1152)           0         ['block6d_activation_DCNN_A[0]
#  Multiply)                                                          [0]',
#                                                                      'block6d_se_expand_DCNN_A[0][
#                                                                     0]']
#
#  block_12_depthwise_BN_DCNN  (None, 14, 14, 576)          2304      ['block_12_depthwise_DCNN_B[0]
#  _B (BatchNormalization)                                            [0]']
#
#  conv3_block3_2_conv_DCNN_C  (None, 28, 28, 128)          147456    ['conv3_block3_2_pad_DCNN_C[0]
#   (Conv2D)                                                          [0]']
#
#  block6d_project_conv_DCNN_  (None, 7, 7, 192)            221184    ['block6d_se_excite_DCNN_A[0][
#  A (Conv2D)                                                         0]']
#
#  block_12_depthwise_relu_DC  (None, 14, 14, 576)          0         ['block_12_depthwise_BN_DCNN_B
#  NN_B (ReLU)                                                        [0][0]']
#
#  conv3_block3_2_bn_DCNN_C (  (None, 28, 28, 128)          512       ['conv3_block3_2_conv_DCNN_C[0
#  BatchNormalization)                                                ][0]']
#
#  block6d_project_bn_DCNN_A   (None, 7, 7, 192)            768       ['block6d_project_conv_DCNN_A[
#  (BatchNormalization)                                               0][0]']
#
#  block_12_project_DCNN_B (C  (None, 14, 14, 96)           55296     ['block_12_depthwise_relu_DCNN
#  onv2D)                                                             _B[0][0]']
#
#  conv3_block3_2_relu_DCNN_C  (None, 28, 28, 128)          0         ['conv3_block3_2_bn_DCNN_C[0][
#   (Activation)                                                      0]']
#
#  block6d_drop_DCNN_A (Dropo  (None, 7, 7, 192)            0         ['block6d_project_bn_DCNN_A[0]
#  ut)                                                                [0]']
#
#  block_12_project_BN_DCNN_B  (None, 14, 14, 96)           384       ['block_12_project_DCNN_B[0][0
#   (BatchNormalization)                                              ]']
#
#  conv3_block3_3_conv_DCNN_C  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu_DCNN_C[0
#   (Conv2D)                                                          ][0]']
#
#  block6d_add_DCNN_A (Add)    (None, 7, 7, 192)            0         ['block6d_drop_DCNN_A[0][0]',
#                                                                      'block6c_add_DCNN_A[0][0]']
#
#  block_12_add_DCNN_B (Add)   (None, 14, 14, 96)           0         ['block_11_add_DCNN_B[0][0]',
#                                                                      'block_12_project_BN_DCNN_B[0
#                                                                     ][0]']
#
#  conv3_block3_out_DCNN_C (A  (None, 28, 28, 512)          0         ['conv3_block2_out_DCNN_C[0][0
#  dd)                                                                ]',
#                                                                      'conv3_block3_3_conv_DCNN_C[0
#                                                                     ][0]']
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 192)            37056     ['block6d_add_DCNN_A[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 192)            1179840   ['block_12_add_DCNN_B[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 23, 23, 192)          3539136   ['conv3_block3_out_DCNN_C[0][0
#                                                                     ]']
#
#  average_pooling2d_3 (Avera  (None, 7, 7, 192)            0         ['conv2d_3[0][0]']
#  gePooling2D)
#
#  average_pooling2d_4 (Avera  (None, 7, 7, 192)            0         ['conv2d_4[0][0]']
#  gePooling2D)
#
#  average_pooling2d_5 (Avera  (None, 7, 7, 192)            0         ['conv2d_5[0][0]']
#  gePooling2D)
#
#  alpha_dropout_3 (AlphaDrop  (None, 7, 7, 192)            0         ['average_pooling2d_3[0][0]']
#  out)
#
#  alpha_dropout_4 (AlphaDrop  (None, 7, 7, 192)            0         ['average_pooling2d_4[0][0]']
#  out)
#
#  alpha_dropout_5 (AlphaDrop  (None, 7, 7, 192)            0         ['average_pooling2d_5[0][0]']
#  out)
#
#  InitialFusionLayer (Add)    (None, 7, 7, 192)            0         ['alpha_dropout_3[0][0]',
#                                                                      'alpha_dropout_4[0][0]',
#                                                                      'alpha_dropout_5[0][0]']
#
#  batch_normalization (Batch  (None, 7, 7, 192)            768       ['InitialFusionLayer[0][0]']
#  Normalization)
#
#  tf.nn.selu (TFOpLambda)     (None, 7, 7, 192)            0         ['batch_normalization[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 7, 7, 192)            37056     ['tf.nn.selu[0][0]']
#
#  batch_normalization_1 (Bat  (None, 7, 7, 192)            768       ['conv2d_6[0][0]']
#  chNormalization)
#
#  tf.nn.selu_1 (TFOpLambda)   (None, 7, 7, 192)            0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 192)            37056     ['tf.nn.selu_1[0][0]']
#
#  FuRB (Add)                  (None, 7, 7, 192)            0         ['InitialFusionLayer[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  global_average_pooling2d (  (None, 192)                  0         ['FuRB[0][0]']
#  GlobalAveragePooling2D)
#
#  alpha_dropout_6 (AlphaDrop  (None, 192)                  0         ['global_average_pooling2d[0][
#  out)                                                               0]']
#
#  Softmax_ClassifierMFuReCNN  (None, 4)                    772       ['alpha_dropout_6[0][0]']
#  _alpha_do_Learning_rate_0.
#  01 (Dense)
#
# ==================================================================================================
# Total params: 9474935 (36.14 MB)
# Trainable params: 4831684 (18.43 MB)
# Non-trainable params: 4643251 (17.71 MB)
# __________________________________________________________________________________________________
# Complete and ready for compilation and training!

# %%
last_conv_layer_name = mfurecnn.layers[-4].name

if last_conv_layer_name == 'ResidualFusionLayer':
    print("CORRECT LAYER SELECTED:", last_conv_layer_name)
else:
    print("INCORRECT LAYER SELECTED:", last_conv_layer_name)
    print("Please Reselect")
# Out:
# INCORRECT LAYER SELECTED: FuRB
# Please Reselect

# %%
import datetime
import pickle
import os
import time
import psutil
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# Generate timestamp
timestamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

#MODEL COMPILATION WITH HYPER-PARAMETERS, LOSS FUNCTIONS AND TRAINING!

mfurecnn.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy']) 

reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=2,
                              verbose=1, mode='max')

callbacks = [reduce_lr]

# MODEL TRAINING
start_time = time.time()

history = mfurecnn.fit(train_generator, steps_per_epoch=nb_train_samples // batch_size,
                                  epochs=epochs, validation_data=validation_generator,
                                  callbacks=callbacks, 
                                  validation_steps=nb_validation_samples // batch_size, verbose=1)


elapsed_time = time.time() - start_time
train_time = time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
memory_usage = psutil.Process(os.getpid()).memory_info().rss / (1024 ** 3)  # in GB
print()
print()
print(train_time, 'train_time')
print()
print(elapsed_time, 'Seconds')
print()
print()
print("MODEL SERIALIZING WAIT FOR A MOMENT...")
print()

#SAVE AFTER TRAINING COMPLETES
model_save_dir = f"models/{architecture}"
os.makedirs(model_save_dir, exist_ok=True)

model_filename = f"{model_save_dir}/{architecture}_{timestamp}_model.h5"
history_filename = f"{model_save_dir}/{architecture}_{timestamp}_history.pickle"
weights_filename = f"{model_save_dir}/{architecture}_{timestamp}.h5"
json_filename = f"{model_save_dir}/{architecture}_{timestamp}.json"
results_filename = f"{model_save_dir}/{architecture}_{timestamp}_results.txt"

mfurecnn.save(model_filename)

# Save the history for evaluation
def save_h(file, history):
    with open(file, 'wb') as file_pi:
        pickle.dump(history, file_pi)
    print(f"History saved to {file}")

save_h(history_filename, history.history)

print("\n\nThe Model weights and history are successfully trained and saved!\n")
# Out:
# Epoch 1/25
# 400/400 [==============================] - 640s 2s/step - loss: 8.1974 - accuracy: 0.7628 - val_loss: 1.0367 - val_accuracy: 0.8695 - lr: 0.0100
# Epoch 2/25
# 400/400 [==============================] - 626s 2s/step - loss: 0.4641 - accuracy: 0.8494 - val_loss: 1.0434 - val_accuracy: 0.8745 - lr: 0.0100
# Epoch 3/25
# 400/400 [==============================] - 634s 2s/step - loss: 0.4374 - accuracy: 0.8644 - val_loss: 1.7100 - val_accuracy: 0.8640 - lr: 0.0100
# Epoch 4/25
# 400/400 [==============================] - 627s 2s/step - loss: 0.4632 - accuracy: 0.8650 - val_loss: 0.6411 - val_accuracy: 0.9150 - lr: 0.0100
# Epoch 5/25
# 400/400 [==============================] - 626s 2s/step - loss: 0.4859 - accuracy: 0.8603 - val_loss: 2.2863 - val_accuracy: 0.8285 - lr: 0.0100
# Epoch 6/25
# 400/400 [==============================] - 628s 2s/step - loss: 0.5233 - accuracy: 0.8544 - val_loss: 1.0189 - val_accuracy: 0.9165 - lr: 0.0100
# Epoch 7/25
# 400/400 [==============================] - 628s 2s/step - loss: 0.4567 - accuracy: 0.8697 - val_loss: 1.7946 - val_accuracy: 0.8700 - lr: 0.0100
# Epoch 8/25
# 400/400 [==============================] - 610s 2s/step - loss: 0.4764 - accuracy: 0.8694 - val_loss: 2.7026 - val_accuracy: 0.8115 - lr: 0.0100
# Epoch 9/25
# 400/400 [==============================] - 608s 2s/step - loss: 0.6007 - accuracy: 0.8475 - val_loss: 6.1714 - val_accuracy: 0.7585 - lr: 0.0100
# Epoch 10/25
# 400/400 [==============================] - 610s 2s/step - loss: 0.4837 - accuracy: 0.8687 - val_loss: 7.2682 - val_accuracy: 0.7075 - lr: 0.0100
# Epoch 11/25
# 400/400 [==============================] - 610s 2s/step - loss: 0.4776 - accuracy: 0.8641 - val_loss: 2.6970 - val_accuracy: 0.8580 - lr: 0.0100
# Epoch 12/25
# 400/400 [==============================] - 610s 2s/step - loss: 0.4820 - accuracy: 0.8684 - val_loss: 8.6579 - val_accuracy: 0.6880 - lr: 0.0100
# Epoch 13/25
# 400/400 [==============================] - 612s 2s/step - loss: 0.5894 - accuracy: 0.8709 - val_loss: 5.0405 - val_accuracy: 0.7900 - lr: 0.0100
# Epoch 14/25
# 400/400 [==============================] - 611s 2s/step - loss: 0.4508 - accuracy: 0.8719 - val_loss: 5.3536 - val_accuracy: 0.7650 - lr: 0.0100
# Epoch 15/25
# 400/400 [==============================] - 609s 2s/step - loss: 0.4519 - accuracy: 0.8844 - val_loss: 6.5926 - val_accuracy: 0.7120 - lr: 0.0100
# Epoch 16/25
# 400/400 [==============================] - 610s 2s/step - loss: 0.4222 - accuracy: 0.8888 - val_loss: 8.2266 - val_accuracy: 0.6750 - lr: 0.0100
# Epoch 17/25
# 400/400 [==============================] - 610s 2s/step - loss: 0.4142 - accuracy: 0.8863 - val_loss: 6.3160 - val_accuracy: 0.8060 - lr: 0.0100
# Epoch 18/25
# 400/400 [==============================] - 610s 2s/step - loss: 0.5370 - accuracy: 0.8778 - val_loss: 6.0902 - val_accuracy: 0.7390 - lr: 0.0100
# Epoch 19/25
# 400/400 [==============================] - 613s 2s/step - loss: 0.4667 - accuracy: 0.8691 - val_loss: 8.6661 - val_accuracy: 0.7135 - lr: 0.0100
# Epoch 20/25
# 400/400 [==============================] - 612s 2s/step - loss: 0.4311 - accuracy: 0.8856 - val_loss: 11.8969 - val_accuracy: 0.6120 - lr: 0.0100
# Epoch 21/25
# 400/400 [==============================] - 610s 2s/step - loss: 0.4230 - accuracy: 0.8903 - val_loss: 31.4217 - val_accuracy: 0.5845 - lr: 0.0100
# Epoch 22/25
# 400/400 [==============================] - 612s 2s/step - loss: 0.5265 - accuracy: 0.8709 - val_loss: 55.2483 - val_accuracy: 0.3820 - lr: 0.0100
# Epoch 23/25
# 400/400 [==============================] - 614s 2s/step - loss: 0.5031 - accuracy: 0.8775 - val_loss: 26.4714 - val_accuracy: 0.4870 - lr: 0.0100
# Epoch 24/25
# 400/400 [==============================] - 612s 2s/step - loss: 0.5138 - accuracy: 0.8863 - val_loss: 9.6556 - val_accuracy: 0.6885 - lr: 0.0100
# Epoch 25/25
# 400/400 [==============================] - 615s 2s/step - loss: 0.4391 - accuracy: 0.8950 - val_loss: 15.3350 - val_accuracy: 0.6095 - lr: 0.0100
#
#
# 04:16:49 train_time
#
# 15409.872690200806 Seconds
#
#
# MODEL SERIALIZING WAIT FOR A MOMENT...
# c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# History saved to models/MFuReCNN_alpha_do_Learning_rate_0.01/MFuReCNN_alpha_do_Learning_rate_0.01_20240808-233637_history.pickle
#
#
# The Model weights and history are successfully trained and saved!

# %%
# Reload the trained model

model = load_model(model_filename)
print("The model is loaded")
# Out:
# The model is loaded

# %%
# Save model to JSON and weights
def save_m(weights_file, json_file, model):
    model.save_weights(weights_file)
    model_json = model.to_json()
    with open(json_file, "w") as json_file:
        json_file.write(model_json)
    print(f"Model weights saved to {weights_file}")
    print(f"Model structure saved to {json_file}")

save_m(weights_filename, json_filename, model)
# Out:
# Model weights saved to models/MFuReCNN_alpha_do_Learning_rate_0.01/MFuReCNN_alpha_do_Learning_rate_0.01_20240808-233637.h5
# Model structure saved to <_io.TextIOWrapper name='models/MFuReCNN_alpha_do_Learning_rate_0.01/MFuReCNN_alpha_do_Learning_rate_0.01_20240808-233637.json' mode='w' encoding='cp1252'>

# %%
# Evaluate on test data
test_loss, test_acc = model.evaluate(test_generator, steps=nb_test_samples // batch_size)
Y_pred = model.predict(test_generator, steps=nb_test_samples // batch_size)
y_pred = np.argmax(Y_pred, axis=1)

# Confusion Matrix
cm = confusion_matrix(test_generator.classes, y_pred)
cr = classification_report(test_generator.classes, y_pred, target_names=test_generator.class_indices.keys())

# Save results
def save_results(filename, history, train_time, memory_usage, nb_train_samples, nb_validation_samples, nb_test_samples, test_acc, test_loss, cm, cr):
    with open(filename, 'w') as f:
        f.write(f"Training Time: {train_time}\n")
        f.write(f"Memory Usage: {memory_usage:.2f} GB\n")
        f.write(f"Number of Training Samples: {nb_train_samples}\n")
        f.write(f"Number of Validation Samples: {nb_validation_samples}\n")
        f.write(f"Number of Test Samples: {nb_test_samples}\n")
        f.write(f"Test Accuracy: {test_acc}\n")
        f.write(f"Test Loss: {test_loss}\n")
        
        f.write("\nTraining Accuracy and Loss per Epoch:\n")
        for epoch, (acc, loss) in enumerate(zip(history['accuracy'], history['loss'])):
            f.write(f"Epoch {epoch+1}: Accuracy={acc}, Loss={loss}\n")
        
        f.write("\nValidation Accuracy and Loss per Epoch:\n")
        for epoch, (val_acc, val_loss) in enumerate(zip(history['val_accuracy'], history['val_loss'])):
            f.write(f"Epoch {epoch+1}: Val Accuracy={val_acc}, Val Loss={val_loss}\n")
        
        f.write("\nConfusion Matrix:\n")
        f.write(np.array2string(cm))
        
        f.write("\n\nClassification Report:\n")
        f.write(cr)

    print(f"Results saved to {filename}")

save_results(results_filename, history.history, train_time, memory_usage, nb_train_samples, nb_validation_samples, nb_test_samples, test_acc, test_loss, cm, cr)

print("\nAll results have been saved!")
# Out:
# 100/100 [==============================] - 76s 741ms/step - loss: 14.4719 - accuracy: 0.6413
# 100/100 [==============================] - 74s 720ms/step
# Results saved to models/MFuReCNN_alpha_do_Learning_rate_0.01/MFuReCNN_alpha_do_Learning_rate_0.01_20240808-233637_results.txt
#
# All results have been saved!

# %%
# Save accuracy and loss per epoch
def save_accuracy_loss(filename, history):
    with open(filename, 'w') as f:
        f.write("Epoch\tAccuracy\tLoss\tVal Accuracy\tVal Loss\n")
        for epoch in range(len(history['accuracy'])):
            acc = history['accuracy'][epoch]
            loss = history['loss'][epoch]
            val_acc = history['val_accuracy'][epoch]
            val_loss = history['val_loss'][epoch]
            f.write(f"{epoch+1}\t{acc}\t{loss}\t{val_acc}\t{val_loss}\n")
    print(f"Accuracy and loss per epoch saved to {filename}")

# Add this to the end of your existing code after saving the model and history
accuracy_loss_filename = f"{model_save_dir}/{architecture}_{timestamp}_accuracy_loss.txt"
save_accuracy_loss(accuracy_loss_filename, history.history)
# Out:
# Accuracy and loss per epoch saved to models/MFuReCNN_alpha_do_Learning_rate_0.01/MFuReCNN_alpha_do_Learning_rate_0.01_20240808-233637_accuracy_loss.txt
